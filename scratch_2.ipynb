# %%
import pandas as pd
import numpy as np
import re

#Webscraping
import requests
from requests import get
from bs4 import BeautifulSoup
import time

# %%
df = pd.read_csv('data/michelin_my_maps.csv')

# %%
df.head()
# Out:
#                                Name  \
# 0                        King's Joy
# 1  Xin Rong Ji (Xinyuan South Road)
# 2                       Taian Table
# 3        Ultraviolet by Paul Pairet
# 4                            Quince
#
#                                              Address  \
# 0        2 Wudaoying Hutong, Beijing, China Mainland
# 1  1F, East Tower, Genesis Beijing, 8 Xinyuan Sou...
# 2  101-102, Building No. 1, Garden Office, No.161...
# 3  'somewhere in Shanghai' - meet at Mr & Mrs Bun...
# 4        470 Pacific Ave., San Francisco, 94133, USA
#
#                    Location Price                    Cuisine   Longitude  \
# 0   Beijing, China Mainland   ¥¥¥                 Vegetarian  116.410004
# 1   Beijing, China Mainland  ¥¥¥¥                    Taizhou  116.450148
# 2  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.474049
# 3  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.485090
# 4        San Francisco, USA  $$$$  Contemporary, Californian -122.403261
#
#     Latitude   PhoneNumber                                                Url  \
# 0  39.946681  8.610840e+11  https://guide.michelin.com/en/beijing-municipa...
# 1  39.946380  8.610650e+11  https://guide.michelin.com/en/beijing-municipa...
# 2  31.221807  8.617302e+12  https://guide.michelin.com/en/shanghai-municip...
# 3  31.240358           NaN  https://guide.michelin.com/en/shanghai-municip...
# 4  37.797505  1.415776e+10  https://guide.michelin.com/en/california/san-f...
#
#                         WebsiteUrl             Award  \
# 0                              NaN  3 MICHELIN Stars
# 1                              NaN  3 MICHELIN Stars
# 2          https://taian-table.cn/  3 MICHELIN Stars
# 3               https://uvbypp.cc/  3 MICHELIN Stars
# 4  http://www.quincerestaurant.com  3 MICHELIN Stars
#
#                                FacilitiesAndServices
# 0  Air conditioning,American Express credit card,...
# 1  Air conditioning,Car park,China UnionPay,Count...
# 2  Air conditioning,American Express credit card,...
# 3  Air conditioning,American Express credit card,...
# 4  Air conditioning,American Express credit card,...

# %%
def clean_michelin(df):
    #Make all column names lowercase
    df.columns = df.columns.str.lower()
    #renaming columns in snake case
    df = df.rename(columns = {"phonenumber":"phone_number",
                              "websiteurl":"website_url", "facilitiesandservices":"facilities_and_services"})
    return df

# %%
df = clean_michelin(df)
df.head()
# Out:
#                                name  \
# 0                        King's Joy
# 1  Xin Rong Ji (Xinyuan South Road)
# 2                       Taian Table
# 3        Ultraviolet by Paul Pairet
# 4                            Quince
#
#                                              address  \
# 0        2 Wudaoying Hutong, Beijing, China Mainland
# 1  1F, East Tower, Genesis Beijing, 8 Xinyuan Sou...
# 2  101-102, Building No. 1, Garden Office, No.161...
# 3  'somewhere in Shanghai' - meet at Mr & Mrs Bun...
# 4        470 Pacific Ave., San Francisco, 94133, USA
#
#                    location price                    cuisine   longitude  \
# 0   Beijing, China Mainland   ¥¥¥                 Vegetarian  116.410004
# 1   Beijing, China Mainland  ¥¥¥¥                    Taizhou  116.450148
# 2  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.474049
# 3  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.485090
# 4        San Francisco, USA  $$$$  Contemporary, Californian -122.403261
#
#     latitude  phone_number                                                url  \
# 0  39.946681  8.610840e+11  https://guide.michelin.com/en/beijing-municipa...
# 1  39.946380  8.610650e+11  https://guide.michelin.com/en/beijing-municipa...
# 2  31.221807  8.617302e+12  https://guide.michelin.com/en/shanghai-municip...
# 3  31.240358           NaN  https://guide.michelin.com/en/shanghai-municip...
# 4  37.797505  1.415776e+10  https://guide.michelin.com/en/california/san-f...
#
#                        website_url             award  \
# 0                              NaN  3 MICHELIN Stars
# 1                              NaN  3 MICHELIN Stars
# 2          https://taian-table.cn/  3 MICHELIN Stars
# 3               https://uvbypp.cc/  3 MICHELIN Stars
# 4  http://www.quincerestaurant.com  3 MICHELIN Stars
#
#                              facilities_and_services
# 0  Air conditioning,American Express credit card,...
# 1  Air conditioning,Car park,China UnionPay,Count...
# 2  Air conditioning,American Express credit card,...
# 3  Air conditioning,American Express credit card,...
# 4  Air conditioning,American Express credit card,...

# %%
#Hardcoding the url for first restaurant
url = 'https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/king-s-joy'

# %%
#Checking connection
response = get(url)
response
# Out:
# <Response [200]>

# %%
#Soup factory
request = requests.get(url)
soup = BeautifulSoup(request.content, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="full-screen-mobile" dir="" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="" name="author"/>
# <meta content="#fff" name="theme-color"/>
# <meta content="vFUp7XI3G-xKLevkT2qftuscMInOxirdCu0oYr7_uLM" name="google-site-verification">
# <meta content="eZwPBJ-0r-9qysyJy_aEPti-m_vr-h_oUJy2qUR1144" name="google-site-verification">
# <meta content="Article" property="og:type">
# <meta content="MICHELIN Guide" property="og:site_name">
# <meta content="https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/king-s-joy" property="og:url"/>
# <meta content="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c?width=1000" property="og:image"/>
# <meta content="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c?width=1000" itemprop="image"/>
# <meta content="King's Joy – Beijing - a MICHELIN Guide Restaurant" itemprop="name"/>
# <meta content="King's Joy – Beijing - a MICHELIN Guide Restaurant" property="og:title">
# <title>King's Joy – Beijing - a MICHELIN Guide Restaurant</title>
# <meta content="King's Joy – a Three MICHELIN Stars: Exceptional cuisine, worth a special journey! restaurant in the 2023 MICHELIN Guide Global. The MICHELIN inspectors’ point of view, information on prices, types of cuisine and opening hours on the MICHELIN Guide's official website" itemprop="description"/>
# <meta content="King's Joy – a Three MICHELIN Stars: Exceptional cuisine, worth a special journey! restaurant in the 2023 MICHELIN Guide Global. The MICHELIN inspectors’ point of view, information on prices, types of cuisine and opening hours on the MICHELIN Guide's official website" property="og:description">
# <meta content="King's Joy – a Three MICHELIN Stars: Exceptional cuisine, worth a special journey! restaurant in the 2023 MICHELIN Guide Global. The MICHELIN inspectors’ point of view, information on prices, types of cuisine and opening hours on the MICHELIN Guide's official website" name="description"/>
# <meta content="michelin_revamp" name="layout">
# <link href="https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/king-s-joy" rel="canonical"/>
# <link href="https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="x-default" rel="alternate"/>
# <link href="https://guide.michelin.com/ae-az/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-ae" rel="alternate"/>
# <link href="https://guide.michelin.com/at/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-at" rel="alternate"/>
# <link href="https://guide.michelin.com/be/fr/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="fr-be" rel="alternate"/>
# <link href="https://guide.michelin.com/be/nl/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="nl-be" rel="alternate"/>
# <link href="https://guide.michelin.com/br/pt_BR/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="pt-br" rel="alternate"/>
# <link href="https://guide.michelin.com/ca/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-ca" rel="alternate"/>
# <link href="https://guide.michelin.com/hr/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-hr" rel="alternate"/>
# <link href="https://guide.michelin.com/cz/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-cz" rel="alternate"/>
# <link href="https://guide.michelin.com/dk/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-dk" rel="alternate"/>
# <link href="https://guide.michelin.com/ae-du/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-ae" rel="alternate"/>
# <link href="https://guide.michelin.com/es/es/beijing-municipality/beijing/restaurante/king-s-joy" hreflang="es-es" rel="alternate"/>
# <link href="https://guide.michelin.com/ee/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-ee" rel="alternate"/>
# <link href="https://guide.michelin.com/fi/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-fi" rel="alternate"/>
# <link href="https://guide.michelin.com/fr/fr/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="fr-fr" rel="alternate"/>
# <link href="https://guide.michelin.com/de/de/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="de-de" rel="alternate"/>
# <link href="https://guide.michelin.com/gr/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-gr" rel="alternate"/>
# <link href="https://guide.michelin.com/hk/zh_HK/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="zh-hk" rel="alternate"/>
# <link href="https://guide.michelin.com/hk/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-hk" rel="alternate"/>
# <link href="https://guide.michelin.com/hu/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-hu" rel="alternate"/>
# <link href="https://guide.michelin.com/is/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-is" rel="alternate"/>
# <link href="https://guide.michelin.com/it/it/beijing-municipality/beijing/ristorante/king-s-joy" hreflang="it-it" rel="alternate"/>
# <link href="https://guide.michelin.com/jp/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-jp" rel="alternate"/>
# <link href="https://guide.michelin.com/jp/ja/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="ja-jp" rel="alternate"/>
# <link href="https://guide.michelin.com/lu/fr/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="fr-lu" rel="alternate"/>
# <link href="https://guide.michelin.com/mo/zh_HK/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="zh-mo" rel="alternate"/>
# <link href="https://guide.michelin.com/mo/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-mo" rel="alternate"/>
# <link href="https://guide.michelin.com/my/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-my" rel="alternate"/>
# <link href="https://guide.michelin.com/mt/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-mt" rel="alternate"/>
# <link href="https://guide.michelin.com/nl/nl/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="nl-nl" rel="alternate"/>
# <link href="https://guide.michelin.com/no/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-no" rel="alternate"/>
# <link href="https://guide.michelin.com/pl/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-pl" rel="alternate"/>
# <link href="https://guide.michelin.com/pt/pt_PT/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="pt-pt" rel="alternate"/>
# <link href="https://guide.michelin.com/ie/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-ie" rel="alternate"/>
# <link href="https://guide.michelin.com/kr/ko/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="ko-kr" rel="alternate"/>
# <link href="https://guide.michelin.com/kr/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-kr" rel="alternate"/>
# <link href="https://guide.michelin.com/rs/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-rs" rel="alternate"/>
# <link href="https://guide.michelin.com/sg/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-sg" rel="alternate"/>
# <link href="https://guide.michelin.com/sg/zh_CN/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="zh-sg" rel="alternate"/>
# <link href="https://guide.michelin.com/si/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-si" rel="alternate"/>
# <link href="https://guide.michelin.com/se/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-se" rel="alternate"/>
# <link href="https://guide.michelin.com/ch/fr/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="fr-ch" rel="alternate"/>
# <link href="https://guide.michelin.com/ch/it/beijing-municipality/beijing/ristorante/king-s-joy" hreflang="it-ch" rel="alternate"/>
# <link href="https://guide.michelin.com/ch/de/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="de-ch" rel="alternate"/>
# <link href="https://guide.michelin.com/tw/zh_TW/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="zh-tw" rel="alternate"/>
# <link href="https://guide.michelin.com/tw/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-tw" rel="alternate"/>
# <link href="https://guide.michelin.com/th/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-th" rel="alternate"/>
# <link href="https://guide.michelin.com/th/th/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="th-th" rel="alternate"/>
# <link href="https://guide.michelin.com/tr/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-tr" rel="alternate"/>
# <link href="https://guide.michelin.com/tr/tr/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="tr-tr" rel="alternate"/>
# <link href="https://guide.michelin.com/gb/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-gb" rel="alternate"/>
# <link href="https://guide.michelin.com/us/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-us" rel="alternate"/>
# <title>MICHELIN Guide – the official website</title>
# <link href="/assets/favicon/favicon-1.png" rel="apple-touch-icon"/>
# <link href="/assets/favicon/favicon-1.png" rel="icon" sizes="48x53" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link as="font" crossorigin="" href="/assets/web/fonts/annuel/Annuels-f9aa99019cb3d27806d129e37c3d657f.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="/assets/web/fonts/michelin-guide-icon/michelin-guide-icon-51ed18b3704a7d4da32d9606fc52266f.ttf" rel="preload"/>
# <!-- Font awesome -->
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.8.2/css/all.css" integrity="sha384-xVVam1KS4+Qt2OrFa+VdRUoXygyKIuNWUUUBZYv+n27STsJ7oDOHJgfF0bNKLMJF" rel="stylesheet"/>
# <!-- End awesome -->
# <link href="/assets/web/app.restaurant-fd4595cc30b46af9df5444587d1703f5.css" rel="stylesheet">
# <noscript>
# <link href="/assets/web/frontend/noscript-79dd52db209c9b2d7f56f0a347d2a95d.css" rel="stylesheet">
# </link></noscript>
# <!-- Global JS variables start -->
# <script type="text/javascript">
#         window.GTM_ENVIRONMENT = 'Prod';
#         window.dataLayer = window.dataLayer || [];
#         window.dLayer = window.dLayer || {};
#     </script>
# <!-- Global JS variables end -->
# <script data-vendor="didomi:google" type="didomi/javascript">
#         (function(b,o,i,l,e,r){b.GoogleAnalyticsObject=l;b[l]||(b[l]=
#             function(){(b[l].q=b[l].q||[]).push(arguments)});b[l].l=+new Date;
#             e=o.createElement(i);r=o.getElementsByTagName(i)[0];
#             e.src='https://www.google-analytics.com/analytics.js';
#             r.parentNode.insertBefore(e,r)}(window,document,'script','ga'));
#         ga('create','UA-76077827-8');ga('send','pageview');
#     </script>
# <script async="async" data-vendor="didomi:google" src="https://www.googletagservices.com/tag/js/gpt.js" type="didomi/javascript"></script>
# <script data-vendor="didomi:google" type="didomi/javascript">
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         googletag.cmd.push(function() {
#             googletag.pubads().enableSingleRequest();
#             googletag.enableServices();
#         });
#     </script>
# <!-- Didomi cookiesent -->
# <script type="text/javascript">
#             window.didomiConfig = {"regulations":{"ccpa":{"enabled":true,"lspa":false}},"notice":{"content":{"dismiss":{"fr":"Accepter et fermer","en":"Agree and close","de":"Zustimmen und schließen","it":"Accetta e chiudi","es":"Aceptar y cerrar","pt":"Aceitar e fechar","nl":"Akkoord en sluiten"},"learnMore":{"fr":"Paramétrer","en":"Manage my settings","de":"Einstellungen verwalten","it":"Per configurare","es":"Configuración","pt":"Configuração","nl":"Cookie-instellingen"}}},"preferences":{"content":{"disagreeToAll":{"fr":"Tout refuser","en":"Refuse all","de":"Lehne alles ab","it":"Rifiutare tutto","es":"Rechazar todo","pt":"Recusar tudo","nl":"Weiger alles"},"agreeToAll":{"fr":"Tout accepter","en":"Accept all","de":"Alles akzeptieren","it":"Accetta tutto","es":"Acepta todo","pt":"Aceite tudo","nl":"Accepteer alles"}}}};
#             if (typeof window.didomiConfig.notice !== 'undefined') {
#                 window.didomiConfig.notice.enable = true;
#             }
#         </script>
# <script type="text/javascript">window.gdprAppliesGlobally=true;(function(){function r(){if(!window.frames.__cmpLocator){if(document.body&&document.body.firstChild){var e=document.body;var t=document.createElement("iframe");
#         t.style.display="none";t.name="__cmpLocator";t.title="cmpLocator";
#         e.insertBefore(t,e.firstChild)}else{setTimeout(r,5)}}}function e(e,t,r){if(typeof r!=="function"){return}if(!window.__cmpBuffer){window.__cmpBuffer=[]}if(e==="ping"){r({gdprAppliesGlobally:window.gdprAppliesGlobally,cmpLoaded:false},true)}else{window.__cmpBuffer.push({command:e,parameter:t,callback:r})}}e.stub=true;
#         function t(a){if(!window.__cmp||window.__cmp.stub!==true){return}if(!a.data){return}var n=typeof a.data==="string";var e;
#             try{e=n?JSON.parse(a.data):a.data}catch(t){return}if(e.__cmpCall){var o=e.__cmpCall;window.__cmp(o.command,o.parameter,function(e,t){var r={__cmpReturn:{returnValue:e,success:t,callId:o.callId}};
#                 a.source.postMessage(n?JSON.stringify(r):r,"*")})}}if(typeof window.__cmp!=="function"){window.__cmp=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}r()})();(function(e,t){var r=document.createElement("script");
#         r.id="spcloader";r.type="text/javascript";r.async=true;r.src="https://sdk.privacy-center.org/"+e+"/loader.js?target_type=notice&target="+t;r.charset="utf-8";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(r,a)})("dc737c7b-2d4e-404e-860c-31cff0a656ec", "BgU9wFNR");</script>
# <!-- End Didomi cookiesent -->
# <script type="text/javascript">
#
#     /**
#      * Validate auth expiry
#      * @param authObject the auth object from local storage
#      * @returns {boolean}
#      */
#     var validateAuthExpiry = function (authObject) {
#         if (!authObject) return false;
#         try {
#             if (authObject.hasOwnProperty("expires_in")) {
#                 var date = new Date();
#                 if (date.getTime() < authObject.expires_in) {
#                     return true;
#                 }
#             }
#         } catch (e) {
#             // noop
#         }
#         return false;
#     };
#
#     /**
#      * Checks whether device signed in
#      * @returns {boolean}
#      */
#     var isSignedIn = function () {
#         try {
#             var authStorage = localStorage.getItem("auth");
#             var authObject = JSON.parse(authStorage);
#             return validateAuthExpiry(authObject);
#         } catch (e) {
#             // noop
#         }
#         return false;
#     };
#
#     window.IS_SIGNED_IN = isSignedIn();
#
# </script>
# <script type="text/javascript">
#
#     window.GTM_ENVIRONMENT = window.GTM_ENVIRONMENT || 'Dev';
#     dLayer['environment'] = window.GTM_ENVIRONMENT;
#     dLayer['language'] = 'en';
#     dLayer['category'] = 'restaurant.datasheet';
#     dLayer['guide'] = 'Global';
#     dLayer['event'] = 'Country.Global.en';
#     dLayer['country'] = 'en';
#
#
#
#         dLayer['cookingtype'] = 'sg.michelin.guide.response.RespReference\u004063f2d243';
#         dLayer['region'] = 'Beijing Municipality';
#         dLayer['city'] = 'Beijing';
#         dLayer['district'] = 'Dongcheng';
#         dLayer['distinction'] = '3 star';
#         dLayer['id'] = '75130';
#         dLayer['restaurant_name'] = 'King\u0027s Joy';
#         dLayer['chef'] = 'Gary YIN';
#         dLayer['online_booking'] = 'False';
#         dLayer['price'] = 'CAT_P03';
#         dLayer['restaurant_selection'] = 'Global';
#         dLayer['restaurant_country'] = 'cn';
#
#
#
#     dLayer['isSignedIn'] = window.IS_SIGNED_IN;
#
#     window.dataLayer = window.dataLayer || [];
#
#         window.dataLayer.push(dLayer);
#
#
# </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-NND8XGT');</script>
# <!-- End Google Tag Manager -->
# </link></meta></meta></meta></meta></meta></meta></meta></head>
# <body class="lang-en" data-accept-cookie-url="/en/public-rest/acceptCookie">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NND8XGT" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!--[if lt IE 10]>
#   <p class="browserupgrade">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
# <![endif]-->
# <!-- Start Navbar -->
# <header class="header-wrapper js-navbar">
# <nav class="d-flex header js-header">
# <!-- Start Logo -->
# <div class="header__logo">
# <a aria-label="Go to Homepage" href="/en">
# <img alt="MICHELIN Guide" height="42" src="/assets/images/michelin-guide-logo-dark.svg" width="237"/>
# </a>
# </div>
# <!-- Start Menu -->
# <div class="header__nav">
# <div class="header__menu">
# <ul class="header__menu--list">
# <li class="item active">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.restaurants" data-guide="Global" href="/en">
#                         Restaurants
#                     </a>
# </li>
# <li class="item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.hotels" data-guide="Global" href="/en/hotels">
#                             Hotels
#                         </a>
# </li>
# <li class="item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.magazine" data-guide="Global" href="/en/articles">
#                         Magazine
#                     </a>
# </li>
# <li class="item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.favorites" data-guide="Global" href="/en/restaurantlist">
#                         My Favorites
#                     </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- Start Menu -->
# <!-- Start Toggle Account Menu -->
# <div class="header__account">
# <button aria-label="Menu" class="header__account--button js-open-menubar js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.menu" data-guide="Global" type="button">
# <img alt="" class="image-round js-img-profile-menu" src="/assets/images/icons/account-background-white-d446652af60dee82e04d3afd9419050e.svg">
# <span class="header__account--button-icon">
# <i class="burger-menu"></i>
# </span>
# </img></button>
# </div>
# <!-- End Toggle Account Menu -->
# </nav>
# </header>
# <!-- End Navbar -->
# <!-- Start Menu List Item -->
# <div class="menubar js-menubar">
# <div class="menubar-wrapper">
# <div class="menubar-content">
# <ul class="menubar-content--list js-menu__container">
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Restaurants" data-guide="Global" href="/en/restaurants" target="_self">Restaurants</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Hotels" data-guide="Global" href="/en/hotels-stays" target="_self">Hotels</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.bestof_guides" data-guide="Global" href="/en/best-of" target="_self">Best-of Guides</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Magazine" data-guide="Global" href="/en/articles" target="_self">Magazine</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.subscribe_nl" data-guide="Global" href="/en/subscribe" target="_self">Subscribe to our newsletter</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.bookingpartnerpage" data-guide="Global" href="https://guide.michelin.com/en/take-advantage-of-the-privileged-partnership-between-the-michelin-guide-thefork-and-tripadvisor" rel="nofollow noopener" target="_blank">TheFork prefered partnership</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.bookingpartnerwebsite" data-guide="Global" href="https://www.theforkmanager.com/partnership-thefork-michelin#cc=michelin-referral" rel="nofollow noopener" target="_blank">TheFork partner restaurants</a>
# </li>
# <li class="menubar-content--list-item list-separator"></li>
# <li class="menubar-content--list-item">
# <a class="link link-icon" data-target="#selections-modal" data-toggle="modal" href="#">
# <i class="icon map-marker"></i> Global
#                     </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- End Menu List Item -->
# <!-- Bottom Nav Mobile -->
# <div class="navmobile js-navbar">
# <div class="navmobile-wrapper">
# <div class="navmobile-content">
# <ul class="navmobile-content--list">
# <li class="navmobile-content--list-item">
# <a aria-label="Open Homepage" class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.restaurants" data-guide="Global" href="/en">
# <i class="icon restaurant active"></i>
# </a>
# </li>
# <li class="navmobile-content--list-item">
# <a aria-label="Open Hotels" class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.hotels" data-guide="Global" href="/en/hotels">
# <i class="icon hotel"></i>
# </a>
# </li>
# <li class="navmobile-content--list-item">
# <a aria-label="Open Favorites" class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.favorites" data-guide="Global" href="/en/restaurantlist">
# <i class="icon love"></i>
# </a>
# </li>
# <li class="navmobile-content--list-item">
# <a aria-label="Open Magazine" class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.magazine" data-guide="Global" href="/en/articles">
# <i class="icon magazine"></i>
# </a>
# </li>
# <li class="navmobile-content--list-item">
# <a aria-label="Open Account" class="link js-auth__profile-button js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="account.login" data-guide="Global" href="/en/account">
# <i class="icon account"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- End Bottom Nav Mobile -->
# <main>
# <div class="restaurant-search-wrapper js-restaurants__form">
# <h1 class="section-search--label section-search--label d-block d-lg-none">
#         Restaurants
#     </h1>
# <div class="home-restaurant-search">
# <div class="home-banner-explore">
# <div class="row no-gutters">
# <div class="col col-12 col-xl-5">
# <div class="home-banner-explore__tabs">
# <div class="tabs-container">
# <div class="tab-content">
# <div class="tabs-container__content js-autocomplete__container">
# <div class="tabs-container__content--restaurant">
# <form action="/en/restaurants" data-suggest-url="/en/suggestion" method="get">
# <div class="typeahead__container flex-fill search-explore">
# <span class="search-hotelswrap--close js-close-msearch">
# <i class="fal fa-chevron-left fa-lg"></i>
# </span>
# <div class="typeahead__field">
# <div class="search-explore__item js-autocomplete__search_box" data-article-index="prod-articles-en" data-cities-index="cities-i18n" data-city-guide-base="/en/best-of" data-city-guide-icon="fa fa-compass" data-city-guide-index="prod-cityguides-en" data-city-guide-label="Best-of guides" data-dtm-country="en" data-dtm-guide="Global" data-global-search="/en/search" data-language="en" data-language-base="/en" data-location-icon="fa-map-marker-alt" data-location-index="prod-locations-en" data-location-label="Locations" data-max-facet-items="" data-references-url="/en/public-rest/references.json" data-restaurant-icon="fa-utensils" data-restaurant-index="prod-restaurants-en" data-restaurant-label="Restaurants" data-restaurants-base="/en/restaurants" data-search-city-guide="/en/search?type=city_guide" data-search-placeholder="Search for Destination, restaurant ..." data-search-q="" data-site-code="global" data-site-level="GLOBAL" data-site-name="Global" data-whitelisted-sites="">
# <input class="js-search__q" name="q" type="hidden" value=""/>
# <div class="form-control search-explore__item--input js-search__field js-toggle-msearch"></div>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="search-explore-result js-explore-result">
# <div class="input-group input-search">
# <div class="typeahead__container flex-fill">
# <div class="typeahead__result js-autocomplete__search_results">
# <div class="typeahead__list js-autocomplete__search_hits"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Start Masthead -->
# <div class="masthead masthead__gallery js-masthead-gallery">
# <div class="masthead__gallery-wrapper js-gallery-wrapper">
# <button class="masthead__gallery-open js-gallery-button" data-target="#js-gallery-masthead" data-toggle="modal" type="button">
# <span class="masthead__gallery-open--number">7</span>
# <span class="masthead__gallery-open--base"></span>
# </button>
# <div class="masthead__gallery-image" data-bg="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c?width=1000">
# <div class="masthead__gallery-image-item" data-category="restaurant.datasheet" data-country="en" data-guide="Global" data-image-id="4786526" data-image-source="cloud_image" data-target="#js-gallery-masthead" data-toggle="modal">
# <img alt="" ci-src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c"/>
# <noscript>
# <img alt="" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c">
# </img></noscript>
# </div>
# <div class="masthead__gallery-image-item" data-category="restaurant.datasheet" data-country="en" data-guide="Global" data-image-id="4786554" data-image-source="cloud_image" data-target="#js-gallery-masthead" data-toggle="modal">
# <img alt="" ci-src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/0b633b28b0234d1a93258cb49f7f0632"/>
# <noscript>
# <img alt="" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/0b633b28b0234d1a93258cb49f7f0632">
# </img></noscript>
# </div>
# <div class="masthead__gallery-image-item" data-category="restaurant.datasheet" data-country="en" data-guide="Global" data-image-id="2072250" data-image-source="cloud_image" data-target="#js-gallery-masthead" data-toggle="modal">
# <img alt="" ci-src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/ff032e8012ae488c9572ab1e42fb2e52"/>
# <noscript>
# <img alt="" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/ff032e8012ae488c9572ab1e42fb2e52">
# </img></noscript>
# </div>
# </div>
# </div>
# </div>
# <!-- End Masthead -->
# <div class="restaurant-details">
# <div class="container">
# <div class="row">
# <div class="col-xl-4 order-xl-8 col-lg-5 order-lg-7 restaurant-details__aside">
# <div class="restaurant-details__heading d-lg-none" id="online-booking">
# <div class="restaurant-details__heading--label d-flex">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/gastronomie-durable-da572d846714b6dc47b903cc42ee4899.svg"/></span>
# </div>
# <h1 class="restaurant-details__heading--title">King's Joy</h1>
# <ul class="restaurant-details__heading--list">
# <li class="restaurant-details__heading--address">2 Wudaoying Hutong, Beijing, China Mainland</li>
# <li class="restaurant-details__heading-price">
# <span class="">
#
#                         ¥¥¥
#                         ·
#
#
#
#                         Vegetarian
#
#
#                 </span>
# </li>
# </ul>
# <div class="restaurant-details__likeinfo box-placeholder js-favorite-restaurant" data-add-favorite="Add to favorites" data-category="restaurant.datasheet" data-cooking-type="sg.michelin.guide.response.RespReference@63f2d243" data-country="en" data-dtm-chef="Gary YIN" data-dtm-city="Beijing" data-dtm-distinction="3 star" data-dtm-district="Dongcheng" data-dtm-id="1186733" data-dtm-online-booking="False" data-dtm-price="CAT_P03" data-dtm-region="Beijing Municipality" data-enabled="false" data-guide="Global" data-language="en" data-pid="1186733" data-restaurant-country="cn" data-restaurant-name="King's Joy" data-restaurant-selection="Global" data-saved="Saved">
# <img alt="" class="love-this pl-image" src="/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg"/>
# <p class="restaurant-details__likeinfo--description pl-text js-favorite__description">
#             Add to favorites
#         </p>
# </div>
# </div>
# <!-- Start restaurant Booking -->
# <div class="restaurant-details__booking--wrapper js-booking-sticky">
# <div class="restaurant-details__booking--container">
# <div class="restaurant-details__booking">
# <div class="restaurant-details__booking--title-wrapper">
# <h6 class="restaurant-details__booking--title">
#         Reservations are not available for this restaurant on our site
#     </h6>
# <a class="btn btn-primary btn-block" href="/en/restaurants/online-reservation">
#         Find bookable restaurants near me
#     </a>
# </div>
# </div>
# </div>
# </div>
# <!-- End restaurant Booking -->
# </div>
# <div class="col-xl-8 col-lg-7 restaurant-details__components">
# <!-- Start Section -->
# <section class="section restaurant-details__main">
# <div class="restaurant-details__heading d-none d-lg-block" id="online-booking-desktop">
# <div class="restaurant-details__heading--label d-flex">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/gastronomie-durable-da572d846714b6dc47b903cc42ee4899.svg"/></span>
# </div>
# <h1 class="restaurant-details__heading--title">King's Joy</h1>
# <ul class="restaurant-details__heading--list">
# <li class="restaurant-details__heading--address">2 Wudaoying Hutong, Beijing, China Mainland</li>
# <li class="restaurant-details__heading-price">
# <span class="">
#
#                         ¥¥¥
#                         ·
#
#
#
#                         Vegetarian
#
#
#                 </span>
# </li>
# </ul>
# <div class="restaurant-details__likeinfo box-placeholder js-favorite-restaurant" data-add-favorite="Add to favorites" data-category="restaurant.datasheet" data-cooking-type="sg.michelin.guide.response.RespReference@63f2d243" data-country="en" data-dtm-chef="Gary YIN" data-dtm-city="Beijing" data-dtm-distinction="3 star" data-dtm-district="Dongcheng" data-dtm-id="1186733" data-dtm-online-booking="False" data-dtm-price="CAT_P03" data-dtm-region="Beijing Municipality" data-enabled="false" data-guide="Global" data-language="en" data-pid="1186733" data-restaurant-country="cn" data-restaurant-name="King's Joy" data-restaurant-selection="Global" data-saved="Saved">
# <img alt="" class="love-this pl-image" src="/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg"/>
# <p class="restaurant-details__likeinfo--description pl-text js-favorite__description">
#             Add to favorites
#         </p>
# </div>
# </div>
# <!-- Start restaurant detail description -->
# <div class="restaurant-details__description">
# <div class="restaurant-details__description--heading">
# <h2 class="restaurant-details__description--heading-title">
#                                 MICHELIN Guide’s Point Of View
#                             </h2>
# </div>
# <div class="restaurant-details__classification">
# <div class="restaurant-details__classification--list">
# <div class="classification-item">
# <div class="classfication-content">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/></span>
# </div>
# <div class="classfication-content">
#                                                 Three MICHELIN Stars: Exceptional cuisine, worth a special journey!
#                                             </div>
# </div>
# </div>
# </div>
# <div class="restaurant-details__description--text">
# <p><p>Just a stone’s throw from Yonghe Temple, this serene restaurant is remodelled from a courtyard house and features a glass-roofed dining room. The chef honed his skills at his grandparents’ restaurant of the same name. Only set menus are available; try the classic menu to sample their specialities all at once. Regulars may opt for the solar-term menu that changes every 15 days. Live harp performance befits the restaurant’s classy elegance.</p></p>
# </div>
# </div>
# <!-- End restaurant detail description -->
# <div class="restaurant-details__text-componets">
# <div class="restaurant-details__text-componets--text">
# <div class="restaurant-details__description--heading">
# <h2 class="restaurant-details__description--heading-title">
#                                         Gastronomy &amp; Sustainability
#                                     </h2>
# </div>
# <div class="restaurant-details__classification">
# <div class="restaurant-details__classification--list">
# <div class="classification-item">
# <div class="classfication-content">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/gastronomie-durable-da572d846714b6dc47b903cc42ee4899.svg"/></span>
# </div>
# <div class="classfication-content">
#                                                 MICHELIN Green Star
#                                             </div>
# </div>
# </div>
# </div>
# <blockquote class="restaurant-details__blockquote">
# <p>"We offer vegetarian cuisine using green and seasonal produce that is sourced from local, organic farms. We strive to reduce energy and resource consumption by recycling and banning disposable items. We also promote a sustainable lifestyle through community activities."</p>
# </blockquote>
# <div class="restaurant-details__description--author">
# <span>— Gary YIN</span>
# </div>
# </div>
# </div>
# </section>
# <!-- End Section -->
# <!-- Start Section -->
# <section class="section section-main section__text-componets">
# <div class="restaurant-details__description--heading">
# <h2 class="restaurant-details__description--heading-title">
#                                 Facilities &amp; Services
#                             </h2>
# </div>
# <div class="restaurant-details__services">
# <ul class="row restaurant-details__services--list">
# <li>
#                                             Air conditioning
#                                         </li>
# <li>
#                                             American Express credit card
#                                         </li>
# <li>
#                                             Car park
#                                         </li>
# <li>
#                                             China UnionPay
#                                         </li>
# <li>
#                                             Credit card / Debit card accepted
#                                         </li>
# <li>
#                                             Diners Club credit card
#                                         </li>
# <li>
#                                             Garden or park
#                                         </li>
# <li>
#                                             JCB
#                                         </li>
# <li>
#                                             Maestro
#                                         </li>
# <li>
#                                             Mastercard credit card
#                                         </li>
# <li>
#                                             Particularly interesting wine list
#                                         </li>
# <li>
#                                             Restaurant offering vegetarian menus
#                                         </li>
# <li>
#                                             Terrace
#                                         </li>
# <li>
#                                             Valet parking
#                                         </li>
# <li>
#                                             Visa credit card
#                                         </li>
# <li>
#                                             Wheelchair access
#                                         </li>
# </ul>
# <div class="clearfix"></div>
# </div>
# </section>
# <!-- End Section -->
# <!-- Start Section -->
# <section class="section section-main section__text-componets">
# <div class="section-header">
# <h2 class="section__heading_title">
#                             Information
#                         </h2>
# </div>
# <div class="row">
# <div class="col-md-6">
# <div class="collapse__block">
# <!-- Start collapse 1 -->
# <div class="collapse__block-item">
# <div class="collapse__block-title">
# <div class="d-flex">
# <span class="flex-fill" dir="ltr" x-ms-format-detection="none">
#                                                     +86 10 8404 9191
#                                                 </span>
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-cooking-type="sg.michelin.guide.response.RespReference@63f2d243" data-event="CTA_tel" data-restaurant-distinction="3 star" data-restaurant-name="King's Joy" href="tel:+86 10 8404 9191"></a>
# </div>
# </div>
# </div>
# <!-- End collapse 1 -->
# </div>
# </div>
# <div class="col-md-6">
# <div class="google-map__static">
# <iframe frameborder="0" src="https://www.google.com/maps/embed/v1/place?key=AIzaSyDvEyVCVpGtn81z5NrMKgdehPsrO9sJiMw&amp;q=2 Wudaoying Hutong, Beijing&amp;language=en-US"></iframe>
# </div>
# <!-- for Share Social Mobile View -->
# <div id="share-sosial-mobile"></div>
# </div>
# </div>
# </section>
# <!-- End Section -->
# </div>
# </div>
# </div>
# <!-- End Section -->
# <!-- Start section desktop -->
# <div class="d-none d-lg-block">
# <!-- Start Section Restaurant Nearby -->
# <section class="section-main">
# <div class="container">
# <div class="section-header have-slider-nav">
# <h2 class="section__heading section__heading_title">
#                         Nearby Restaurants
#                     </h2>
# <div class="btn-carousel hide-not-dekstop">
# <button class="btn btn-outline-secondary btn-sm btn-carousel__link js-prev-carousel" data-target="js-owl-carousel-nearby">
# <i class="icon fal fa-angle-left"></i>
# </button>
# <button class="btn btn-outline-secondary btn-sm btn-carousel__link js-next-carousel" data-target="js-owl-carousel-nearby">
# <i class="icon fal fa-angle-right"></i>
# </button>
# </div>
# </div>
# <div class="section-main-content">
# <div class="owl-mobile-fitwidth owl-card-box">
# <div class="owl-carousel owl-theme" data-padding="0" id="js-owl-carousel-nearby">
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height js-map" data-id="75095" data-index="" data-lat="39.9475229" data-lng="116.4116729">
# <div class="card__menu-image">
# <a aria-label="Open Mansion Cuisine by Jingyan" class="image-wrapper pl-image" data-category="restaurant.datasheet" data-ci-bg-url="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/58112f5668c349408731444635ed950e" data-country="en" data-guide="Global" data-image-id="2004477" data-image-source="cloud_image" data-position-x="50" data-position-y="50" href="/en/beijing-municipality/beijing/restaurant/jing-yan-by-chef-duan">
# <noscript><img alt="" height="203" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/58112f5668c349408731444635ed950e" width="362"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/></span>
# </div>
# <h3 class="card__menu-content--title pl-text pl-big">
# <a aria-label="Open Mansion Cuisine by Jingyan" href="/en/beijing-municipality/beijing/restaurant/jing-yan-by-chef-duan">
#                 Mansion Cuisine by Jingyan
#             </a>
# </h3>
# <div class="card__menu-footer--location flex-fill pl-text">
#             Beijing, China Mainland
#         </div>
# <div class="card__menu-footer--price pl-text">
#
#                 ¥¥¥¥
#                 ·
#
#
#                 Beijing Cuisine
#
#
#         </div>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-like box-placeholder js-favorite-restaurant" data-category="restaurant.datasheet" data-cooking-type="Beijing Cuisine" data-country="en" data-dtm-chef="" data-dtm-city="Beijing" data-dtm-distinction="1 star" data-dtm-district="Dongcheng" data-dtm-id="1196639" data-dtm-online-booking="False" data-dtm-price="2,000-999 CNY" data-dtm-region="Beijing Municipality" data-enabled="false" data-guide="Global" data-language="en" data-pid="1196639" data-restaurant-country="cn" data-restaurant-name="Mansion Cuisine by Jingyan" data-restaurant-selection="Beijing">
# <img alt="" class="love-this pl-image" src="/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg"/>
# </div>
# </div>
# <a aria-label="Open Mansion Cuisine by Jingyan" class="link with-love" href="/en/beijing-municipality/beijing/restaurant/jing-yan-by-chef-duan"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height js-map" data-id="75074" data-index="" data-lat="39.93938" data-lng="116.41201">
# <div class="card__menu-image">
# <a aria-label="Open Yu De Fu" class="image-wrapper pl-image" data-category="restaurant.datasheet" data-ci-bg-url="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/9f1b7e270294459c913a8026b1234691" data-country="en" data-guide="Global" data-image-id="2005194" data-image-source="cloud_image" data-position-x="50" data-position-y="50" href="/en/beijing-municipality/beijing/restaurant/yu-de-fu">
# <noscript><img alt="" height="203" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/9f1b7e270294459c913a8026b1234691" width="362"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# </div>
# <h3 class="card__menu-content--title pl-text pl-big">
# <a aria-label="Open Yu De Fu" href="/en/beijing-municipality/beijing/restaurant/yu-de-fu">
#                 Yu De Fu
#             </a>
# </h3>
# <div class="card__menu-footer--location flex-fill pl-text">
#             Beijing, China Mainland
#         </div>
# <div class="card__menu-footer--price pl-text">
#
#                 ¥¥
#                 ·
#
#
#                 Hotpot
#
#
#         </div>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-like box-placeholder js-favorite-restaurant" data-category="restaurant.datasheet" data-cooking-type="Hotpot" data-country="en" data-dtm-chef="" data-dtm-city="Beijing" data-dtm-distinction="" data-dtm-district="Dongcheng" data-dtm-id="1186821" data-dtm-online-booking="False" data-dtm-price="150 CNY" data-dtm-region="Beijing Municipality" data-enabled="false" data-guide="Global" data-language="en" data-pid="1186821" data-restaurant-country="cn" data-restaurant-name="Yu De Fu" data-restaurant-selection="Beijing">
# <img alt="" class="love-this pl-image" src="/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg">
# </img></div>
# </div>
# <a aria-label="Open Yu De Fu" class="link with-love" href="/en/beijing-municipality/beijing/restaurant/yu-de-fu"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height js-map" data-id="75035" data-index="" data-lat="39.95238" data-lng="116.402769">
# <div class="card__menu-image">
# <a aria-label="Open Huaiyang Fu" class="image-wrapper pl-image" data-category="restaurant.datasheet" data-ci-bg-url="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/f87a9f70ab1c468eb4ca2022944b30a2" data-country="en" data-guide="Global" data-image-id="2207356" data-image-source="cloud_image" data-position-x="50" data-position-y="50" href="/en/beijing-municipality/beijing/restaurant/huaiyang-fu">
# <noscript><img alt="" height="203" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/f87a9f70ab1c468eb4ca2022944b30a2" width="362"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/></span>
# </div>
# <h3 class="card__menu-content--title pl-text pl-big">
# <a aria-label="Open Huaiyang Fu" href="/en/beijing-municipality/beijing/restaurant/huaiyang-fu">
#                 Huaiyang Fu
#             </a>
# </h3>
# <div class="card__menu-footer--location flex-fill pl-text">
#             Beijing, China Mainland
#         </div>
# <div class="card__menu-footer--price pl-text">
#
#                 ¥¥
#                 ·
#
#
#                 Huaiyang
#
#
#         </div>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-like box-placeholder js-favorite-restaurant" data-category="restaurant.datasheet" data-cooking-type="Huaiyang" data-country="en" data-dtm-chef="" data-dtm-city="Beijing" data-dtm-distinction="1 star" data-dtm-district="Dongcheng" data-dtm-id="1186722" data-dtm-online-booking="False" data-dtm-price="300 CNY" data-dtm-region="Beijing Municipality" data-enabled="false" data-guide="Global" data-language="en" data-pid="1186722" data-restaurant-country="cn" data-restaurant-name="Huaiyang Fu" data-restaurant-selection="Beijing">
# <img alt="" class="love-this pl-image" src="/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg"/>
# </div>
# </div>
# <a aria-label="Open Huaiyang Fu" class="link with-love" href="/en/beijing-municipality/beijing/restaurant/huaiyang-fu"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height js-map" data-id="75122" data-index="" data-lat="39.937846" data-lng="116.410128">
# <div class="card__menu-image">
# <a aria-label="Open Pang Mei Noodles (Dongcheng)" class="image-wrapper pl-image" data-category="restaurant.datasheet" data-ci-bg-url="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/ae44bc9dc4554089b62341842dea46b9" data-country="en" data-guide="Global" data-image-id="1996013" data-image-source="cloud_image" data-position-x="50" data-position-y="50" href="/en/beijing-municipality/beijing/restaurant/pang-mei-noodles">
# <noscript><img alt="" height="203" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/ae44bc9dc4554089b62341842dea46b9" width="362"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/bib-gourmand-1cdd0611ba6b620ab4815bed020274dd.svg"/></span>
# </div>
# ...
#             </button>
#         </div>
#
#         <div class="modal-body">
#             <div class="modal-account--content">
#                 <form action="#" method="POST" class="js-auth__profile">
#                     <p class="modal-account--content-tagline">
#                         Select how you prefer your name to appear alongside your photo and include a brief bio if you like.
#                     </p>
#                     {{#error}}
#                     <div class="alert alert-danger js-auth__error-box" role="alert">
#                         {{error}}
#                     </div>
#                     {{/error}}
#                     <div>Display my name as:</div>
#
#                     <div class="modal-account--forms {{#nameNotChecked}}is-invalid{{/nameNotChecked}}">
#                         <div class="form-group modal-account--forms-radio">
#                             <input class="radio-button js-reg__profile_name"
#                                    type="radio"
#                                    name="publicName"
#                                    value="{{fullName}}"
#                                    {{#fullNameChecked}}checked{{/fullNameChecked}}/>
#                             <label for="fullNameProfile">{{fullName}}</label><br>
#                         </div>
#
#                         <div class="form-group modal-account--forms-radio">
#                             <input class="radio-button js-reg__profile_firstname"
#                                    type="radio"
#                                    name="publicName"
#                                    value="{{firstName}}"
#                                    {{^fullNameChecked}}checked{{/fullNameChecked}}/>
#                             <label for="firstNameProfile">{{firstName}}</label><br>
#                         </div>
#                     </div>
#
#                     <div class="form-group">
#                         <label for="about">
#                             About me:
#                         </label>
#                         <input type="text"
#                                class="form-control form-control-borderless js-auth__input-about"
#                                autocomplete="off"
#                                name="about"
#                                placeholder="A few words about yourself"
#                                value="{{about}}"/>
#                     </div>
#
#                     <div class="modal-account--forms">
#                         <div class="form-group submit medium-space center">
#                             <button type="submit"
#                                     class="btn btn-primary js-auth__profile-submit"
#                                     data-message-failed-error="Update profile failed. Please try again later."
#                                     data-event="account.register.username"
#                                     data-category="account.register.username"
#                                     data-country="en"
#                                     data-guide="Global">
#                                 Save
#                                 <i class="spinner-border spinner-border-sm loading js-async-loading d-none"></i>
#                             </button>
#                         </div>
#                     </div>
#                 </form>
#             </div>
#         </div>
#     </div>
# </div>
# </script>
# <script id="auth-profile-success" type="x-tmpl-mustache">
# <div class="modal-dialog modal-lg modal-dialog-centered modal-fullscreen-sm-down">
#     <div class="modal-content">
#         <div class="modal-header">
#             <button type="button"
#                     class="close js-dtm-link js-auth__close-modal"
#                     data-dismiss="modal"
#                     data-reload="true"
#                     aria-label="Close"
#                     data-event="account.creation.completion"
#                     data-category="account.registration.done"
#                     data-country="en"
#                     data-guide="Global">
#                 <span aria-hidden="true"><img src="/assets/images/icons/close.svg" width="24" alt=""/></span>
#             </button>
#         </div>
#
#         <div class="modal-body">
#             <div class="modal-account--content center">
#                 <h1 class="modal-account--content-closehead">
#                     Well Done!
#                 </h1>
#
#                 <p class="modal-account--content-tagline left">
#
#                     You can now start liking your favorite restaurants and create your first list by tapping on the <img src="/assets/images/icons/favorite-heart-e6323193a7a0acd16288e7cf61092d46.gif" width="50" alt=""> icon in restaurants and hotels page.
#                 </p>
#
#                 <div class="modal-account--forms">
#                     <div class="form-group submit center">
#                         <button type="button"
#                                 data-dismiss="modal"
#                                 class="btn btn-primary js-dtm-link js-auth__get-started"
#                                 aria-label="Get Started"
#                                 data-event="account.registration.getStarted"
#                                 data-category="account.registration.done"
#                                 data-country="en"
#                                 data-guide="Global"
#                                 data-reload="true">
#                             Get Started
#                         </button>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
# </script>
# <script id="card-menu_hotelprice" type="x-tmpl-mustache">
#     {{#price}}
#         Starting at
#         <span class="card__menu-content--hotelprice-tag">{{price}}</span>
#     {{/price}}
#     {{^price}}
#         {{#onRequest}}
#             On request
#         {{/onRequest}}
#         {{^onRequest}}
#             Sold out
#         {{/onRequest}}
#     {{/price}}
# </script>
# <script type="text/javascript">
#     window.ALGOLIASEARCH_APP_ID = '8NVHRD7ONV';
#     window.ALGOLIASEARCH_SEARCH_KEY = '3222e669cf890dc73fa5f38241117ba5';
#     window.CLOUDIMAGE_BASE_URL = 'https://axwwgrkdco.cloudimg.io/v7/';
#     window.CLOUDIMAGE_CARD_OPTIONS = 'width=500&sharp=1';
#     window.CLOUDIMAGE_CITY_GUIDE_CARD_OPTIONS = 'width=800&sharp=1';
#     window.CLOUDIMAGE_TOKEN = 'axwwgrkdco';
#     window.DIDOMI_ENABLED = true;
#     window.COOKIE_SECURE = true;
#     window.COOKIE_ACCEPTED = false;
#     window.AWARDS_MAP = {"THREE_STARS":{"icon":"o","label":"3 Stars MICHELIN","awardName":"3 star","slug":"3-stars-michelin"},"TWO_STARS":{"icon":"n","label":"2 Stars MICHELIN","awardName":"2 star","slug":"2-stars-michelin"},"MICHELIN_PLATE":{"icon":"\u2039","label":"The Plate MICHELIN","awardName":"plate","slug":"the-plate-michelin"},"ONE_STAR":{"icon":"m","label":"1 Star MICHELIN","awardName":"1 star","slug":"1-star-michelin"},"BIB_GOURMAND":{"icon":"=","label":"Bib Gourmand","awardName":"bib","slug":"bib-gourmand"}};
#     window.COUNTRIES_MAP = {"pr":{"cname":"puerto-rico","label":"Puerto Rico"},"ps":{"cname":"palestine","label":"Palestine"},"pt":{"cname":"portugal","label":"Portugal"},"pw":{"cname":"palau","label":"Palau"},"py":{"cname":"paraguay","label":"Paraguay"},"qa":{"cname":"qatar","label":"Qatar"},"ad":{"cname":"andorra","label":"Andorra"},"ae":{"cname":"united-arab-emirates","label":"United Arab Emirates"},"af":{"cname":"afghanistan","label":"Afghanistan"},"ag":{"cname":"antigua-and-barbuda","label":"Antigua and Barbuda"},"ai":{"cname":"anguilla","label":"Anguilla"},"al":{"cname":"albania","label":"Albania"},"am":{"cname":"armenia","label":"Armenia"},"an":{"cname":"netherlands-antilles","label":"Netherlands Antilles"},"ao":{"cname":"angola","label":"Angola"},"aq":{"cname":"antarctica","label":"Antarctica"},"ar":{"cname":"argentina","label":"Argentina"},"as":{"cname":"american-samoa","label":"American Samoa"},"at":{"cname":"austria","label":"Austria"},"re":{"cname":"reunion","label":"Reunion"},"au":{"cname":"australia","label":"Australia"},"aw":{"cname":"aruba","label":"Aruba"},"ax":{"cname":"aland-islands","label":"\u00c5land Islands"},"az":{"cname":"azerbaijan","label":"Azerbaijan"},"ro":{"cname":"romania","label":"Romania"},"ba":{"cname":"bosnia-and-herzegovina","label":"Bosnia and Herzegovina"},"bb":{"cname":"barbados","label":"Barbados"},"rs":{"cname":"serbia","label":"Serbia"},"bd":{"cname":"bangladesh","label":"Bangladesh"},"be":{"cname":"belgium","label":"Belgium"},"ru":{"cname":"russia","label":"Russia"},"bf":{"cname":"burkina-faso","label":"Burkina Faso"},"bg":{"cname":"bulgaria","label":"Bulgaria"},"rw":{"cname":"rwanda","label":"Rwanda"},"bh":{"cname":"bahrain","label":"Bahrain"},"bi":{"cname":"burundi","label":"Burundi"},"bj":{"cname":"benin","label":"Benin"},"bl":{"cname":"saint-barthelemy","label":"Saint Barth\u00e9lemy"},"bm":{"cname":"bermuda","label":"Bermuda"},"bn":{"cname":"brunei","label":"Brunei"},"bo":{"cname":"bolivia","label":"Bolivia"},"sa":{"cname":"saudi-arabia","label":"Saudi Arabia"},"bq":{"cname":"bonaire-sint-eustatius-and-saba","label":"Bonaire, Sint Eustatius and Saba"},"sb":{"cname":"solomon-islands","label":"Solomon Islands"},"br":{"cname":"brazil","label":"Brazil"},"sc":{"cname":"seychelles","label":"Seychelles"},"bs":{"cname":"bahamas","label":"Bahamas"},"sd":{"cname":"sudan","label":"Sudan"},"bt":{"cname":"bhutan","label":"Bhutan"},"se":{"cname":"sweden","label":"Sweden"},"bv":{"cname":"bouvet-island","label":"Bouvet Island"},"sg":{"cname":"singapore","label":"Singapore"},"bw":{"cname":"botswana","label":"Botswana"},"sh":{"cname":"saint-helena","label":"Saint Helena"},"si":{"cname":"slovenia","label":"Slovenia"},"by":{"cname":"belarus","label":"Belarus"},"sj":{"cname":"svalbard-and-jan-mayen","label":"Svalbard And Jan Mayen"},"bz":{"cname":"belize","label":"Belize"},"sk":{"cname":"slovakia","label":"Slovakia"},"sl":{"cname":"sierra-leone","label":"Sierra Leone"},"sm":{"cname":"san-marino","label":"San Marino"},"sn":{"cname":"senegal","label":"Senegal"},"so":{"cname":"somalia","label":"Somalia"},"ca":{"cname":"canada","label":"Canada"},"sr":{"cname":"suriname","label":"Suriname"},"cc":{"cname":"cocos-islands","label":"Cocos Islands"},"ss":{"cname":"south-sudan","label":"South Sudan"},"cd":{"cname":"the-democratic-republic-of-congo","label":"The Democratic Republic Of Congo"},"st":{"cname":"sao-tome-and-principe","label":"Sao Tome And Principe"},"cf":{"cname":"central-african-republic","label":"Central African Republic"},"sv":{"cname":"el-salvador","label":"El Salvador"},"cg":{"cname":"congo","label":"Congo"},"ch":{"cname":"switzerland","label":"Switzerland"},"sx":{"cname":"sint-maarten-dutch-part","label":"Sint Maarten (Dutch part)"},"ci":{"cname":"cote-d-ivoire","label":"C\u00f4te d'Ivoire"},"sy":{"cname":"syria","label":"Syria"},"sz":{"cname":"swaziland","label":"Swaziland"},"ck":{"cname":"cook-islands","label":"Cook Islands"},"cl":{"cname":"chile","label":"Chile"},"cm":{"cname":"cameroon","l ...
#     window.LANGUAGE_CODES_MAP = {"de":"deu","ko":"kor","en":"eng","pt_BR":"por","it":"ita","fr":"fra","es":"spa","ar":"ara","zh_HK":"zho","zh_TW":"zho","th":"tha","ja":"jpn","zh_CN":"zho","nl":"nld","tr":"tur","pt_PT":"por"};
#     window.RESTAURANT_PLACEHOLDER_IMAGES = ["https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/default1.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/default2.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-119577476.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-157185809.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-179536318.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-182146474.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-509105428.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-542825520.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-544123256.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-677785016.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-810733288.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-839150516.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/online_list_default_0.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/online_list_default_1.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_0.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_1.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_2.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_3.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_5.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_6.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_7.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_9.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_10.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_11.jpg"];
#     window.GCJ02_CANDIDATES = ["cn","tw"];
#     window.SITE_NAME_TRANSLATIONS = {};
#     window.TABLETHOTELS_HOTELS_BASE = 'https://www.tablethotels.com';
#     window.TABLETHOTELS_API_OLD_BASE = 'https://www.tablethotels.com';
#     window.TABLETHOTELS_API_BASE = 'https://api.prod.r53.tablethotels.com';
#     window.HOTEL_COUNTRY = '';
#     window.HOTEL_CURRENCY = 'USD';
#     window.HOTEL_VIEWPORT = '';
#     window.CONTENT_OPTIONAL_TAGS = {};
#     window.CONTACT_US_SUBJECTS = {};
#     window.PRICE_CATEGORIES = {"affordable":{"identifier":"CAT_P01","multiplier":1,"label":"On a budget"},"premium":{"identifier":"CAT_P03","multiplier":3,"label":"Special occasion"},"mid-range":{"identifier":"CAT_P02","multiplier":2,"label":"A moderate spend"},"luxury":{"identifier":"CAT_P04","multiplier":4,"label":"Spare no expense"}};
#     window.SITE_CURRENCY = '';
#     window.IS_ACCOUNT_DISABLED = false;
#     window.LOVE_ON_ICON = '/assets/images/icons/love-on-fc56a08bc4382811985ec658b8fd4bf5.svg';
#     window.LOVE_OFF_ICON = '/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg';
# </script>
# <script src="//polyfill.io/v3/polyfill.min.js?features=default,Array.prototype.find,Array.prototype.includes"></script>
# <script charset="utf-8" src="/assets/web/app.guide-d5344bb8f0f777d2d217fa19800d2eac.js" type="text/javascript"></script>
# <script type="application/ld+json">{"@context":"http://schema.org","address":{"@type":"PostalAddress","streetAddress":"2 Wudaoying Hutong","addressLocality":"Beijing","addressCountry":"CHN","addressRegion":"Beijing Municipality"},"name":"King's Joy","image":"https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c?width=1000","@type":"Restaurant","review":{"@type":"Review","datePublished":"2022-12-20T08:09","name":"King's Joy","description":"Just a stone\u2019s throw from Yonghe Temple, this serene restaurant is remodelled from a courtyard house and features a glass-roofed dining room. The chef honed his skills at his grandparents\u2019 ...","author":{"@type":"Person","name":"Michelin Inspector"}},"telephone":"+86 10 8404 9191","knowsLanguage":"en-CN","acceptsReservations":"No","servesCuisine":"Vegetarian","url":"https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/king-s-joy","starRating":"Three MICHELIN Stars: Exceptional cuisine, worth a special journey!","currenciesAccepted":"CNY","paymentAccepted":"American Express credit card, China UnionPay, Credit card / Debit card accepted, Diners Club credit card, JCB, Maestro, Mastercard credit card, Visa credit card","award":"Three MICHELIN Stars: Exceptional cuisine, worth a special journey!","brand":"MICHELIN Guide","hasDriveThroughService":"False","latitude":39.9466810,"longitude":116.4100040,"hasMap":"https://www.google.com/maps/search/?api=1&query=39.9466810%2C116.4100040"}</script>
# </body>
# </html>

# %%
#Located at div class="restaurant-details__description--text
text = soup.find('div', class_='restaurant-details__description--text').text

# %%
print(text)
# Out:
# Just a stone’s throw from Yonghe Temple, this serene restaurant is remodelled from a courtyard house and features a glass-roofed dining room. The chef honed his skills at his grandparents’ restaurant of the same name. Only set menus are available; try the classic menu to sample their specialities all at once. Regulars may opt for the solar-term menu that changes every 15 days. Live harp performance befits the restaurant’s classy elegance.

# %%
#Trying with URL 2 the same way
df.url[1]
# Out:
# 'https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/xin-rong-ji-xinyuan-south-road'

# %%
url2 = 'https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/xin-rong-ji-xinyuan-south-road'

# %%
#Checking connection
response = get(url)
response
# Out:
# <Response [200]>

# %%
#Soup factory
request2 = requests.get(url2)
soup2 = BeautifulSoup(request2.content, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="full-screen-mobile" dir="" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="" name="author"/>
# <meta content="#fff" name="theme-color"/>
# <meta content="vFUp7XI3G-xKLevkT2qftuscMInOxirdCu0oYr7_uLM" name="google-site-verification">
# <meta content="eZwPBJ-0r-9qysyJy_aEPti-m_vr-h_oUJy2qUR1144" name="google-site-verification">
# <meta content="Article" property="og:type">
# <meta content="MICHELIN Guide" property="og:site_name">
# <meta content="https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/king-s-joy" property="og:url"/>
# <meta content="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c?width=1000" property="og:image"/>
# <meta content="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c?width=1000" itemprop="image"/>
# <meta content="King's Joy – Beijing - a MICHELIN Guide Restaurant" itemprop="name"/>
# <meta content="King's Joy – Beijing - a MICHELIN Guide Restaurant" property="og:title">
# <title>King's Joy – Beijing - a MICHELIN Guide Restaurant</title>
# <meta content="King's Joy – a Three MICHELIN Stars: Exceptional cuisine, worth a special journey! restaurant in the 2023 MICHELIN Guide Global. The MICHELIN inspectors’ point of view, information on prices, types of cuisine and opening hours on the MICHELIN Guide's official website" itemprop="description"/>
# <meta content="King's Joy – a Three MICHELIN Stars: Exceptional cuisine, worth a special journey! restaurant in the 2023 MICHELIN Guide Global. The MICHELIN inspectors’ point of view, information on prices, types of cuisine and opening hours on the MICHELIN Guide's official website" property="og:description">
# <meta content="King's Joy – a Three MICHELIN Stars: Exceptional cuisine, worth a special journey! restaurant in the 2023 MICHELIN Guide Global. The MICHELIN inspectors’ point of view, information on prices, types of cuisine and opening hours on the MICHELIN Guide's official website" name="description"/>
# <meta content="michelin_revamp" name="layout">
# <link href="https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/king-s-joy" rel="canonical"/>
# <link href="https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="x-default" rel="alternate"/>
# <link href="https://guide.michelin.com/ae-az/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-ae" rel="alternate"/>
# <link href="https://guide.michelin.com/at/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-at" rel="alternate"/>
# <link href="https://guide.michelin.com/be/fr/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="fr-be" rel="alternate"/>
# <link href="https://guide.michelin.com/be/nl/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="nl-be" rel="alternate"/>
# <link href="https://guide.michelin.com/br/pt_BR/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="pt-br" rel="alternate"/>
# <link href="https://guide.michelin.com/ca/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-ca" rel="alternate"/>
# <link href="https://guide.michelin.com/hr/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-hr" rel="alternate"/>
# <link href="https://guide.michelin.com/cz/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-cz" rel="alternate"/>
# <link href="https://guide.michelin.com/dk/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-dk" rel="alternate"/>
# <link href="https://guide.michelin.com/ae-du/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-ae" rel="alternate"/>
# <link href="https://guide.michelin.com/es/es/beijing-municipality/beijing/restaurante/king-s-joy" hreflang="es-es" rel="alternate"/>
# <link href="https://guide.michelin.com/ee/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-ee" rel="alternate"/>
# <link href="https://guide.michelin.com/fi/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-fi" rel="alternate"/>
# <link href="https://guide.michelin.com/fr/fr/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="fr-fr" rel="alternate"/>
# <link href="https://guide.michelin.com/de/de/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="de-de" rel="alternate"/>
# <link href="https://guide.michelin.com/gr/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-gr" rel="alternate"/>
# <link href="https://guide.michelin.com/hk/zh_HK/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="zh-hk" rel="alternate"/>
# <link href="https://guide.michelin.com/hk/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-hk" rel="alternate"/>
# <link href="https://guide.michelin.com/hu/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-hu" rel="alternate"/>
# <link href="https://guide.michelin.com/is/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-is" rel="alternate"/>
# <link href="https://guide.michelin.com/it/it/beijing-municipality/beijing/ristorante/king-s-joy" hreflang="it-it" rel="alternate"/>
# <link href="https://guide.michelin.com/jp/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-jp" rel="alternate"/>
# <link href="https://guide.michelin.com/jp/ja/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="ja-jp" rel="alternate"/>
# <link href="https://guide.michelin.com/lu/fr/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="fr-lu" rel="alternate"/>
# <link href="https://guide.michelin.com/mo/zh_HK/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="zh-mo" rel="alternate"/>
# <link href="https://guide.michelin.com/mo/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-mo" rel="alternate"/>
# <link href="https://guide.michelin.com/my/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-my" rel="alternate"/>
# <link href="https://guide.michelin.com/mt/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-mt" rel="alternate"/>
# <link href="https://guide.michelin.com/nl/nl/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="nl-nl" rel="alternate"/>
# <link href="https://guide.michelin.com/no/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-no" rel="alternate"/>
# <link href="https://guide.michelin.com/pl/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-pl" rel="alternate"/>
# <link href="https://guide.michelin.com/pt/pt_PT/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="pt-pt" rel="alternate"/>
# <link href="https://guide.michelin.com/ie/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-ie" rel="alternate"/>
# <link href="https://guide.michelin.com/kr/ko/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="ko-kr" rel="alternate"/>
# <link href="https://guide.michelin.com/kr/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-kr" rel="alternate"/>
# <link href="https://guide.michelin.com/rs/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-rs" rel="alternate"/>
# <link href="https://guide.michelin.com/sg/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-sg" rel="alternate"/>
# <link href="https://guide.michelin.com/sg/zh_CN/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="zh-sg" rel="alternate"/>
# <link href="https://guide.michelin.com/si/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-si" rel="alternate"/>
# <link href="https://guide.michelin.com/se/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-se" rel="alternate"/>
# <link href="https://guide.michelin.com/ch/fr/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="fr-ch" rel="alternate"/>
# <link href="https://guide.michelin.com/ch/it/beijing-municipality/beijing/ristorante/king-s-joy" hreflang="it-ch" rel="alternate"/>
# <link href="https://guide.michelin.com/ch/de/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="de-ch" rel="alternate"/>
# <link href="https://guide.michelin.com/tw/zh_TW/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="zh-tw" rel="alternate"/>
# <link href="https://guide.michelin.com/tw/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-tw" rel="alternate"/>
# <link href="https://guide.michelin.com/th/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-th" rel="alternate"/>
# <link href="https://guide.michelin.com/th/th/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="th-th" rel="alternate"/>
# <link href="https://guide.michelin.com/tr/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-tr" rel="alternate"/>
# <link href="https://guide.michelin.com/tr/tr/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="tr-tr" rel="alternate"/>
# <link href="https://guide.michelin.com/gb/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-gb" rel="alternate"/>
# <link href="https://guide.michelin.com/us/en/beijing-municipality/beijing/restaurant/king-s-joy" hreflang="en-us" rel="alternate"/>
# <title>MICHELIN Guide – the official website</title>
# <link href="/assets/favicon/favicon-1.png" rel="apple-touch-icon"/>
# <link href="/assets/favicon/favicon-1.png" rel="icon" sizes="48x53" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link as="font" crossorigin="" href="/assets/web/fonts/annuel/Annuels-f9aa99019cb3d27806d129e37c3d657f.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="/assets/web/fonts/michelin-guide-icon/michelin-guide-icon-51ed18b3704a7d4da32d9606fc52266f.ttf" rel="preload"/>
# <!-- Font awesome -->
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.8.2/css/all.css" integrity="sha384-xVVam1KS4+Qt2OrFa+VdRUoXygyKIuNWUUUBZYv+n27STsJ7oDOHJgfF0bNKLMJF" rel="stylesheet"/>
# <!-- End awesome -->
# <link href="/assets/web/app.restaurant-fd4595cc30b46af9df5444587d1703f5.css" rel="stylesheet">
# <noscript>
# <link href="/assets/web/frontend/noscript-79dd52db209c9b2d7f56f0a347d2a95d.css" rel="stylesheet">
# </link></noscript>
# <!-- Global JS variables start -->
# <script type="text/javascript">
#         window.GTM_ENVIRONMENT = 'Prod';
#         window.dataLayer = window.dataLayer || [];
#         window.dLayer = window.dLayer || {};
#     </script>
# <!-- Global JS variables end -->
# <script data-vendor="didomi:google" type="didomi/javascript">
#         (function(b,o,i,l,e,r){b.GoogleAnalyticsObject=l;b[l]||(b[l]=
#             function(){(b[l].q=b[l].q||[]).push(arguments)});b[l].l=+new Date;
#             e=o.createElement(i);r=o.getElementsByTagName(i)[0];
#             e.src='https://www.google-analytics.com/analytics.js';
#             r.parentNode.insertBefore(e,r)}(window,document,'script','ga'));
#         ga('create','UA-76077827-8');ga('send','pageview');
#     </script>
# <script async="async" data-vendor="didomi:google" src="https://www.googletagservices.com/tag/js/gpt.js" type="didomi/javascript"></script>
# <script data-vendor="didomi:google" type="didomi/javascript">
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         googletag.cmd.push(function() {
#             googletag.pubads().enableSingleRequest();
#             googletag.enableServices();
#         });
#     </script>
# <!-- Didomi cookiesent -->
# <script type="text/javascript">
#             window.didomiConfig = {"regulations":{"ccpa":{"enabled":true,"lspa":false}},"notice":{"content":{"dismiss":{"fr":"Accepter et fermer","en":"Agree and close","de":"Zustimmen und schließen","it":"Accetta e chiudi","es":"Aceptar y cerrar","pt":"Aceitar e fechar","nl":"Akkoord en sluiten"},"learnMore":{"fr":"Paramétrer","en":"Manage my settings","de":"Einstellungen verwalten","it":"Per configurare","es":"Configuración","pt":"Configuração","nl":"Cookie-instellingen"}}},"preferences":{"content":{"disagreeToAll":{"fr":"Tout refuser","en":"Refuse all","de":"Lehne alles ab","it":"Rifiutare tutto","es":"Rechazar todo","pt":"Recusar tudo","nl":"Weiger alles"},"agreeToAll":{"fr":"Tout accepter","en":"Accept all","de":"Alles akzeptieren","it":"Accetta tutto","es":"Acepta todo","pt":"Aceite tudo","nl":"Accepteer alles"}}}};
#             if (typeof window.didomiConfig.notice !== 'undefined') {
#                 window.didomiConfig.notice.enable = true;
#             }
#         </script>
# <script type="text/javascript">window.gdprAppliesGlobally=true;(function(){function r(){if(!window.frames.__cmpLocator){if(document.body&&document.body.firstChild){var e=document.body;var t=document.createElement("iframe");
#         t.style.display="none";t.name="__cmpLocator";t.title="cmpLocator";
#         e.insertBefore(t,e.firstChild)}else{setTimeout(r,5)}}}function e(e,t,r){if(typeof r!=="function"){return}if(!window.__cmpBuffer){window.__cmpBuffer=[]}if(e==="ping"){r({gdprAppliesGlobally:window.gdprAppliesGlobally,cmpLoaded:false},true)}else{window.__cmpBuffer.push({command:e,parameter:t,callback:r})}}e.stub=true;
#         function t(a){if(!window.__cmp||window.__cmp.stub!==true){return}if(!a.data){return}var n=typeof a.data==="string";var e;
#             try{e=n?JSON.parse(a.data):a.data}catch(t){return}if(e.__cmpCall){var o=e.__cmpCall;window.__cmp(o.command,o.parameter,function(e,t){var r={__cmpReturn:{returnValue:e,success:t,callId:o.callId}};
#                 a.source.postMessage(n?JSON.stringify(r):r,"*")})}}if(typeof window.__cmp!=="function"){window.__cmp=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}r()})();(function(e,t){var r=document.createElement("script");
#         r.id="spcloader";r.type="text/javascript";r.async=true;r.src="https://sdk.privacy-center.org/"+e+"/loader.js?target_type=notice&target="+t;r.charset="utf-8";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(r,a)})("dc737c7b-2d4e-404e-860c-31cff0a656ec", "BgU9wFNR");</script>
# <!-- End Didomi cookiesent -->
# <script type="text/javascript">
#
#     /**
#      * Validate auth expiry
#      * @param authObject the auth object from local storage
#      * @returns {boolean}
#      */
#     var validateAuthExpiry = function (authObject) {
#         if (!authObject) return false;
#         try {
#             if (authObject.hasOwnProperty("expires_in")) {
#                 var date = new Date();
#                 if (date.getTime() < authObject.expires_in) {
#                     return true;
#                 }
#             }
#         } catch (e) {
#             // noop
#         }
#         return false;
#     };
#
#     /**
#      * Checks whether device signed in
#      * @returns {boolean}
#      */
#     var isSignedIn = function () {
#         try {
#             var authStorage = localStorage.getItem("auth");
#             var authObject = JSON.parse(authStorage);
#             return validateAuthExpiry(authObject);
#         } catch (e) {
#             // noop
#         }
#         return false;
#     };
#
#     window.IS_SIGNED_IN = isSignedIn();
#
# </script>
# <script type="text/javascript">
#
#     window.GTM_ENVIRONMENT = window.GTM_ENVIRONMENT || 'Dev';
#     dLayer['environment'] = window.GTM_ENVIRONMENT;
#     dLayer['language'] = 'en';
#     dLayer['category'] = 'restaurant.datasheet';
#     dLayer['guide'] = 'Global';
#     dLayer['event'] = 'Country.Global.en';
#     dLayer['country'] = 'en';
#
#
#
#         dLayer['cookingtype'] = 'sg.michelin.guide.response.RespReference\u004063f2d243';
#         dLayer['region'] = 'Beijing Municipality';
#         dLayer['city'] = 'Beijing';
#         dLayer['district'] = 'Dongcheng';
#         dLayer['distinction'] = '3 star';
#         dLayer['id'] = '75130';
#         dLayer['restaurant_name'] = 'King\u0027s Joy';
#         dLayer['chef'] = 'Gary YIN';
#         dLayer['online_booking'] = 'False';
#         dLayer['price'] = 'CAT_P03';
#         dLayer['restaurant_selection'] = 'Global';
#         dLayer['restaurant_country'] = 'cn';
#
#
#
#     dLayer['isSignedIn'] = window.IS_SIGNED_IN;
#
#     window.dataLayer = window.dataLayer || [];
#
#         window.dataLayer.push(dLayer);
#
#
# </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-NND8XGT');</script>
# <!-- End Google Tag Manager -->
# </link></meta></meta></meta></meta></meta></meta></meta></head>
# <body class="lang-en" data-accept-cookie-url="/en/public-rest/acceptCookie">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NND8XGT" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!--[if lt IE 10]>
#   <p class="browserupgrade">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
# <![endif]-->
# <!-- Start Navbar -->
# <header class="header-wrapper js-navbar">
# <nav class="d-flex header js-header">
# <!-- Start Logo -->
# <div class="header__logo">
# <a aria-label="Go to Homepage" href="/en">
# <img alt="MICHELIN Guide" height="42" src="/assets/images/michelin-guide-logo-dark.svg" width="237"/>
# </a>
# </div>
# <!-- Start Menu -->
# <div class="header__nav">
# <div class="header__menu">
# <ul class="header__menu--list">
# <li class="item active">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.restaurants" data-guide="Global" href="/en">
#                         Restaurants
#                     </a>
# </li>
# <li class="item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.hotels" data-guide="Global" href="/en/hotels">
#                             Hotels
#                         </a>
# </li>
# <li class="item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.magazine" data-guide="Global" href="/en/articles">
#                         Magazine
#                     </a>
# </li>
# <li class="item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.favorites" data-guide="Global" href="/en/restaurantlist">
#                         My Favorites
#                     </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- Start Menu -->
# <!-- Start Toggle Account Menu -->
# <div class="header__account">
# <button aria-label="Menu" class="header__account--button js-open-menubar js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.menu" data-guide="Global" type="button">
# <img alt="" class="image-round js-img-profile-menu" src="/assets/images/icons/account-background-white-d446652af60dee82e04d3afd9419050e.svg">
# <span class="header__account--button-icon">
# <i class="burger-menu"></i>
# </span>
# </img></button>
# </div>
# <!-- End Toggle Account Menu -->
# </nav>
# </header>
# <!-- End Navbar -->
# <!-- Start Menu List Item -->
# <div class="menubar js-menubar">
# <div class="menubar-wrapper">
# <div class="menubar-content">
# <ul class="menubar-content--list js-menu__container">
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Restaurants" data-guide="Global" href="/en/restaurants" target="_self">Restaurants</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Hotels" data-guide="Global" href="/en/hotels-stays" target="_self">Hotels</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.bestof_guides" data-guide="Global" href="/en/best-of" target="_self">Best-of Guides</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Magazine" data-guide="Global" href="/en/articles" target="_self">Magazine</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.subscribe_nl" data-guide="Global" href="/en/subscribe" target="_self">Subscribe to our newsletter</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.bookingpartnerpage" data-guide="Global" href="https://guide.michelin.com/en/take-advantage-of-the-privileged-partnership-between-the-michelin-guide-thefork-and-tripadvisor" rel="nofollow noopener" target="_blank">TheFork prefered partnership</a>
# </li>
# <li class="menubar-content--list-item">
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.bookingpartnerwebsite" data-guide="Global" href="https://www.theforkmanager.com/partnership-thefork-michelin#cc=michelin-referral" rel="nofollow noopener" target="_blank">TheFork partner restaurants</a>
# </li>
# <li class="menubar-content--list-item list-separator"></li>
# <li class="menubar-content--list-item">
# <a class="link link-icon" data-target="#selections-modal" data-toggle="modal" href="#">
# <i class="icon map-marker"></i> Global
#                     </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- End Menu List Item -->
# <!-- Bottom Nav Mobile -->
# <div class="navmobile js-navbar">
# <div class="navmobile-wrapper">
# <div class="navmobile-content">
# <ul class="navmobile-content--list">
# <li class="navmobile-content--list-item">
# <a aria-label="Open Homepage" class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.restaurants" data-guide="Global" href="/en">
# <i class="icon restaurant active"></i>
# </a>
# </li>
# <li class="navmobile-content--list-item">
# <a aria-label="Open Hotels" class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.hotels" data-guide="Global" href="/en/hotels">
# <i class="icon hotel"></i>
# </a>
# </li>
# <li class="navmobile-content--list-item">
# <a aria-label="Open Favorites" class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.favorites" data-guide="Global" href="/en/restaurantlist">
# <i class="icon love"></i>
# </a>
# </li>
# <li class="navmobile-content--list-item">
# <a aria-label="Open Magazine" class="link js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.magazine" data-guide="Global" href="/en/articles">
# <i class="icon magazine"></i>
# </a>
# </li>
# <li class="navmobile-content--list-item">
# <a aria-label="Open Account" class="link js-auth__profile-button js-dtm-link" data-category="restaurant.datasheet" data-country="en" data-event="account.login" data-guide="Global" href="/en/account">
# <i class="icon account"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- End Bottom Nav Mobile -->
# <main>
# <div class="restaurant-search-wrapper js-restaurants__form">
# <h1 class="section-search--label section-search--label d-block d-lg-none">
#         Restaurants
#     </h1>
# <div class="home-restaurant-search">
# <div class="home-banner-explore">
# <div class="row no-gutters">
# <div class="col col-12 col-xl-5">
# <div class="home-banner-explore__tabs">
# <div class="tabs-container">
# <div class="tab-content">
# <div class="tabs-container__content js-autocomplete__container">
# <div class="tabs-container__content--restaurant">
# <form action="/en/restaurants" data-suggest-url="/en/suggestion" method="get">
# <div class="typeahead__container flex-fill search-explore">
# <span class="search-hotelswrap--close js-close-msearch">
# <i class="fal fa-chevron-left fa-lg"></i>
# </span>
# <div class="typeahead__field">
# <div class="search-explore__item js-autocomplete__search_box" data-article-index="prod-articles-en" data-cities-index="cities-i18n" data-city-guide-base="/en/best-of" data-city-guide-icon="fa fa-compass" data-city-guide-index="prod-cityguides-en" data-city-guide-label="Best-of guides" data-dtm-country="en" data-dtm-guide="Global" data-global-search="/en/search" data-language="en" data-language-base="/en" data-location-icon="fa-map-marker-alt" data-location-index="prod-locations-en" data-location-label="Locations" data-max-facet-items="" data-references-url="/en/public-rest/references.json" data-restaurant-icon="fa-utensils" data-restaurant-index="prod-restaurants-en" data-restaurant-label="Restaurants" data-restaurants-base="/en/restaurants" data-search-city-guide="/en/search?type=city_guide" data-search-placeholder="Search for Destination, restaurant ..." data-search-q="" data-site-code="global" data-site-level="GLOBAL" data-site-name="Global" data-whitelisted-sites="">
# <input class="js-search__q" name="q" type="hidden" value=""/>
# <div class="form-control search-explore__item--input js-search__field js-toggle-msearch"></div>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="search-explore-result js-explore-result">
# <div class="input-group input-search">
# <div class="typeahead__container flex-fill">
# <div class="typeahead__result js-autocomplete__search_results">
# <div class="typeahead__list js-autocomplete__search_hits"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Start Masthead -->
# <div class="masthead masthead__gallery js-masthead-gallery">
# <div class="masthead__gallery-wrapper js-gallery-wrapper">
# <button class="masthead__gallery-open js-gallery-button" data-target="#js-gallery-masthead" data-toggle="modal" type="button">
# <span class="masthead__gallery-open--number">7</span>
# <span class="masthead__gallery-open--base"></span>
# </button>
# <div class="masthead__gallery-image" data-bg="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c?width=1000">
# <div class="masthead__gallery-image-item" data-category="restaurant.datasheet" data-country="en" data-guide="Global" data-image-id="4786526" data-image-source="cloud_image" data-target="#js-gallery-masthead" data-toggle="modal">
# <img alt="" ci-src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c"/>
# <noscript>
# <img alt="" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c">
# </img></noscript>
# </div>
# <div class="masthead__gallery-image-item" data-category="restaurant.datasheet" data-country="en" data-guide="Global" data-image-id="4786554" data-image-source="cloud_image" data-target="#js-gallery-masthead" data-toggle="modal">
# <img alt="" ci-src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/0b633b28b0234d1a93258cb49f7f0632"/>
# <noscript>
# <img alt="" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/0b633b28b0234d1a93258cb49f7f0632">
# </img></noscript>
# </div>
# <div class="masthead__gallery-image-item" data-category="restaurant.datasheet" data-country="en" data-guide="Global" data-image-id="2072250" data-image-source="cloud_image" data-target="#js-gallery-masthead" data-toggle="modal">
# <img alt="" ci-src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/ff032e8012ae488c9572ab1e42fb2e52"/>
# <noscript>
# <img alt="" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/ff032e8012ae488c9572ab1e42fb2e52">
# </img></noscript>
# </div>
# </div>
# </div>
# </div>
# <!-- End Masthead -->
# <div class="restaurant-details">
# <div class="container">
# <div class="row">
# <div class="col-xl-4 order-xl-8 col-lg-5 order-lg-7 restaurant-details__aside">
# <div class="restaurant-details__heading d-lg-none" id="online-booking">
# <div class="restaurant-details__heading--label d-flex">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/gastronomie-durable-da572d846714b6dc47b903cc42ee4899.svg"/></span>
# </div>
# <h1 class="restaurant-details__heading--title">King's Joy</h1>
# <ul class="restaurant-details__heading--list">
# <li class="restaurant-details__heading--address">2 Wudaoying Hutong, Beijing, China Mainland</li>
# <li class="restaurant-details__heading-price">
# <span class="">
#
#                         ¥¥¥
#                         ·
#
#
#
#                         Vegetarian
#
#
#                 </span>
# </li>
# </ul>
# <div class="restaurant-details__likeinfo box-placeholder js-favorite-restaurant" data-add-favorite="Add to favorites" data-category="restaurant.datasheet" data-cooking-type="sg.michelin.guide.response.RespReference@63f2d243" data-country="en" data-dtm-chef="Gary YIN" data-dtm-city="Beijing" data-dtm-distinction="3 star" data-dtm-district="Dongcheng" data-dtm-id="1186733" data-dtm-online-booking="False" data-dtm-price="CAT_P03" data-dtm-region="Beijing Municipality" data-enabled="false" data-guide="Global" data-language="en" data-pid="1186733" data-restaurant-country="cn" data-restaurant-name="King's Joy" data-restaurant-selection="Global" data-saved="Saved">
# <img alt="" class="love-this pl-image" src="/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg"/>
# <p class="restaurant-details__likeinfo--description pl-text js-favorite__description">
#             Add to favorites
#         </p>
# </div>
# </div>
# <!-- Start restaurant Booking -->
# <div class="restaurant-details__booking--wrapper js-booking-sticky">
# <div class="restaurant-details__booking--container">
# <div class="restaurant-details__booking">
# <div class="restaurant-details__booking--title-wrapper">
# <h6 class="restaurant-details__booking--title">
#         Reservations are not available for this restaurant on our site
#     </h6>
# <a class="btn btn-primary btn-block" href="/en/restaurants/online-reservation">
#         Find bookable restaurants near me
#     </a>
# </div>
# </div>
# </div>
# </div>
# <!-- End restaurant Booking -->
# </div>
# <div class="col-xl-8 col-lg-7 restaurant-details__components">
# <!-- Start Section -->
# <section class="section restaurant-details__main">
# <div class="restaurant-details__heading d-none d-lg-block" id="online-booking-desktop">
# <div class="restaurant-details__heading--label d-flex">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/gastronomie-durable-da572d846714b6dc47b903cc42ee4899.svg"/></span>
# </div>
# <h1 class="restaurant-details__heading--title">King's Joy</h1>
# <ul class="restaurant-details__heading--list">
# <li class="restaurant-details__heading--address">2 Wudaoying Hutong, Beijing, China Mainland</li>
# <li class="restaurant-details__heading-price">
# <span class="">
#
#                         ¥¥¥
#                         ·
#
#
#
#                         Vegetarian
#
#
#                 </span>
# </li>
# </ul>
# <div class="restaurant-details__likeinfo box-placeholder js-favorite-restaurant" data-add-favorite="Add to favorites" data-category="restaurant.datasheet" data-cooking-type="sg.michelin.guide.response.RespReference@63f2d243" data-country="en" data-dtm-chef="Gary YIN" data-dtm-city="Beijing" data-dtm-distinction="3 star" data-dtm-district="Dongcheng" data-dtm-id="1186733" data-dtm-online-booking="False" data-dtm-price="CAT_P03" data-dtm-region="Beijing Municipality" data-enabled="false" data-guide="Global" data-language="en" data-pid="1186733" data-restaurant-country="cn" data-restaurant-name="King's Joy" data-restaurant-selection="Global" data-saved="Saved">
# <img alt="" class="love-this pl-image" src="/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg"/>
# <p class="restaurant-details__likeinfo--description pl-text js-favorite__description">
#             Add to favorites
#         </p>
# </div>
# </div>
# <!-- Start restaurant detail description -->
# <div class="restaurant-details__description">
# <div class="restaurant-details__description--heading">
# <h2 class="restaurant-details__description--heading-title">
#                                 MICHELIN Guide’s Point Of View
#                             </h2>
# </div>
# <div class="restaurant-details__classification">
# <div class="restaurant-details__classification--list">
# <div class="classification-item">
# <div class="classfication-content">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/></span>
# </div>
# <div class="classfication-content">
#                                                 Three MICHELIN Stars: Exceptional cuisine, worth a special journey!
#                                             </div>
# </div>
# </div>
# </div>
# <div class="restaurant-details__description--text">
# <p><p>Just a stone’s throw from Yonghe Temple, this serene restaurant is remodelled from a courtyard house and features a glass-roofed dining room. The chef honed his skills at his grandparents’ restaurant of the same name. Only set menus are available; try the classic menu to sample their specialities all at once. Regulars may opt for the solar-term menu that changes every 15 days. Live harp performance befits the restaurant’s classy elegance.</p></p>
# </div>
# </div>
# <!-- End restaurant detail description -->
# <div class="restaurant-details__text-componets">
# <div class="restaurant-details__text-componets--text">
# <div class="restaurant-details__description--heading">
# <h2 class="restaurant-details__description--heading-title">
#                                         Gastronomy &amp; Sustainability
#                                     </h2>
# </div>
# <div class="restaurant-details__classification">
# <div class="restaurant-details__classification--list">
# <div class="classification-item">
# <div class="classfication-content">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/gastronomie-durable-da572d846714b6dc47b903cc42ee4899.svg"/></span>
# </div>
# <div class="classfication-content">
#                                                 MICHELIN Green Star
#                                             </div>
# </div>
# </div>
# </div>
# <blockquote class="restaurant-details__blockquote">
# <p>"We offer vegetarian cuisine using green and seasonal produce that is sourced from local, organic farms. We strive to reduce energy and resource consumption by recycling and banning disposable items. We also promote a sustainable lifestyle through community activities."</p>
# </blockquote>
# <div class="restaurant-details__description--author">
# <span>— Gary YIN</span>
# </div>
# </div>
# </div>
# </section>
# <!-- End Section -->
# <!-- Start Section -->
# <section class="section section-main section__text-componets">
# <div class="restaurant-details__description--heading">
# <h2 class="restaurant-details__description--heading-title">
#                                 Facilities &amp; Services
#                             </h2>
# </div>
# <div class="restaurant-details__services">
# <ul class="row restaurant-details__services--list">
# <li>
#                                             Air conditioning
#                                         </li>
# <li>
#                                             American Express credit card
#                                         </li>
# <li>
#                                             Car park
#                                         </li>
# <li>
#                                             China UnionPay
#                                         </li>
# <li>
#                                             Credit card / Debit card accepted
#                                         </li>
# <li>
#                                             Diners Club credit card
#                                         </li>
# <li>
#                                             Garden or park
#                                         </li>
# <li>
#                                             JCB
#                                         </li>
# <li>
#                                             Maestro
#                                         </li>
# <li>
#                                             Mastercard credit card
#                                         </li>
# <li>
#                                             Particularly interesting wine list
#                                         </li>
# <li>
#                                             Restaurant offering vegetarian menus
#                                         </li>
# <li>
#                                             Terrace
#                                         </li>
# <li>
#                                             Valet parking
#                                         </li>
# <li>
#                                             Visa credit card
#                                         </li>
# <li>
#                                             Wheelchair access
#                                         </li>
# </ul>
# <div class="clearfix"></div>
# </div>
# </section>
# <!-- End Section -->
# <!-- Start Section -->
# <section class="section section-main section__text-componets">
# <div class="section-header">
# <h2 class="section__heading_title">
#                             Information
#                         </h2>
# </div>
# <div class="row">
# <div class="col-md-6">
# <div class="collapse__block">
# <!-- Start collapse 1 -->
# <div class="collapse__block-item">
# <div class="collapse__block-title">
# <div class="d-flex">
# <span class="flex-fill" dir="ltr" x-ms-format-detection="none">
#                                                     +86 10 8404 9191
#                                                 </span>
# <a class="link js-dtm-link" data-category="restaurant.datasheet" data-cooking-type="sg.michelin.guide.response.RespReference@63f2d243" data-event="CTA_tel" data-restaurant-distinction="3 star" data-restaurant-name="King's Joy" href="tel:+86 10 8404 9191"></a>
# </div>
# </div>
# </div>
# <!-- End collapse 1 -->
# </div>
# </div>
# <div class="col-md-6">
# <div class="google-map__static">
# <iframe frameborder="0" src="https://www.google.com/maps/embed/v1/place?key=AIzaSyDvEyVCVpGtn81z5NrMKgdehPsrO9sJiMw&amp;q=2 Wudaoying Hutong, Beijing&amp;language=en-US"></iframe>
# </div>
# <!-- for Share Social Mobile View -->
# <div id="share-sosial-mobile"></div>
# </div>
# </div>
# </section>
# <!-- End Section -->
# </div>
# </div>
# </div>
# <!-- End Section -->
# <!-- Start section desktop -->
# <div class="d-none d-lg-block">
# <!-- Start Section Restaurant Nearby -->
# <section class="section-main">
# <div class="container">
# <div class="section-header have-slider-nav">
# <h2 class="section__heading section__heading_title">
#                         Nearby Restaurants
#                     </h2>
# <div class="btn-carousel hide-not-dekstop">
# <button class="btn btn-outline-secondary btn-sm btn-carousel__link js-prev-carousel" data-target="js-owl-carousel-nearby">
# <i class="icon fal fa-angle-left"></i>
# </button>
# <button class="btn btn-outline-secondary btn-sm btn-carousel__link js-next-carousel" data-target="js-owl-carousel-nearby">
# <i class="icon fal fa-angle-right"></i>
# </button>
# </div>
# </div>
# <div class="section-main-content">
# <div class="owl-mobile-fitwidth owl-card-box">
# <div class="owl-carousel owl-theme" data-padding="0" id="js-owl-carousel-nearby">
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height js-map" data-id="75095" data-index="" data-lat="39.9475229" data-lng="116.4116729">
# <div class="card__menu-image">
# <a aria-label="Open Mansion Cuisine by Jingyan" class="image-wrapper pl-image" data-category="restaurant.datasheet" data-ci-bg-url="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/58112f5668c349408731444635ed950e" data-country="en" data-guide="Global" data-image-id="2004477" data-image-source="cloud_image" data-position-x="50" data-position-y="50" href="/en/beijing-municipality/beijing/restaurant/jing-yan-by-chef-duan">
# <noscript><img alt="" height="203" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/58112f5668c349408731444635ed950e" width="362"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/></span>
# </div>
# <h3 class="card__menu-content--title pl-text pl-big">
# <a aria-label="Open Mansion Cuisine by Jingyan" href="/en/beijing-municipality/beijing/restaurant/jing-yan-by-chef-duan">
#                 Mansion Cuisine by Jingyan
#             </a>
# </h3>
# <div class="card__menu-footer--location flex-fill pl-text">
#             Beijing, China Mainland
#         </div>
# <div class="card__menu-footer--price pl-text">
#
#                 ¥¥¥¥
#                 ·
#
#
#                 Beijing Cuisine
#
#
#         </div>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-like box-placeholder js-favorite-restaurant" data-category="restaurant.datasheet" data-cooking-type="Beijing Cuisine" data-country="en" data-dtm-chef="" data-dtm-city="Beijing" data-dtm-distinction="1 star" data-dtm-district="Dongcheng" data-dtm-id="1196639" data-dtm-online-booking="False" data-dtm-price="2,000-999 CNY" data-dtm-region="Beijing Municipality" data-enabled="false" data-guide="Global" data-language="en" data-pid="1196639" data-restaurant-country="cn" data-restaurant-name="Mansion Cuisine by Jingyan" data-restaurant-selection="Beijing">
# <img alt="" class="love-this pl-image" src="/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg"/>
# </div>
# </div>
# <a aria-label="Open Mansion Cuisine by Jingyan" class="link with-love" href="/en/beijing-municipality/beijing/restaurant/jing-yan-by-chef-duan"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height js-map" data-id="75074" data-index="" data-lat="39.93938" data-lng="116.41201">
# <div class="card__menu-image">
# <a aria-label="Open Yu De Fu" class="image-wrapper pl-image" data-category="restaurant.datasheet" data-ci-bg-url="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/9f1b7e270294459c913a8026b1234691" data-country="en" data-guide="Global" data-image-id="2005194" data-image-source="cloud_image" data-position-x="50" data-position-y="50" href="/en/beijing-municipality/beijing/restaurant/yu-de-fu">
# <noscript><img alt="" height="203" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/9f1b7e270294459c913a8026b1234691" width="362"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# </div>
# <h3 class="card__menu-content--title pl-text pl-big">
# <a aria-label="Open Yu De Fu" href="/en/beijing-municipality/beijing/restaurant/yu-de-fu">
#                 Yu De Fu
#             </a>
# </h3>
# <div class="card__menu-footer--location flex-fill pl-text">
#             Beijing, China Mainland
#         </div>
# <div class="card__menu-footer--price pl-text">
#
#                 ¥¥
#                 ·
#
#
#                 Hotpot
#
#
#         </div>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-like box-placeholder js-favorite-restaurant" data-category="restaurant.datasheet" data-cooking-type="Hotpot" data-country="en" data-dtm-chef="" data-dtm-city="Beijing" data-dtm-distinction="" data-dtm-district="Dongcheng" data-dtm-id="1186821" data-dtm-online-booking="False" data-dtm-price="150 CNY" data-dtm-region="Beijing Municipality" data-enabled="false" data-guide="Global" data-language="en" data-pid="1186821" data-restaurant-country="cn" data-restaurant-name="Yu De Fu" data-restaurant-selection="Beijing">
# <img alt="" class="love-this pl-image" src="/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg">
# </img></div>
# </div>
# <a aria-label="Open Yu De Fu" class="link with-love" href="/en/beijing-municipality/beijing/restaurant/yu-de-fu"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height js-map" data-id="75035" data-index="" data-lat="39.95238" data-lng="116.402769">
# <div class="card__menu-image">
# <a aria-label="Open Huaiyang Fu" class="image-wrapper pl-image" data-category="restaurant.datasheet" data-ci-bg-url="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/f87a9f70ab1c468eb4ca2022944b30a2" data-country="en" data-guide="Global" data-image-id="2207356" data-image-source="cloud_image" data-position-x="50" data-position-y="50" href="/en/beijing-municipality/beijing/restaurant/huaiyang-fu">
# <noscript><img alt="" height="203" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/f87a9f70ab1c468eb4ca2022944b30a2" width="362"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/1star-1f2c04d7e6738e8a3312c9cda4b64fd0.svg"/></span>
# </div>
# <h3 class="card__menu-content--title pl-text pl-big">
# <a aria-label="Open Huaiyang Fu" href="/en/beijing-municipality/beijing/restaurant/huaiyang-fu">
#                 Huaiyang Fu
#             </a>
# </h3>
# <div class="card__menu-footer--location flex-fill pl-text">
#             Beijing, China Mainland
#         </div>
# <div class="card__menu-footer--price pl-text">
#
#                 ¥¥
#                 ·
#
#
#                 Huaiyang
#
#
#         </div>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-like box-placeholder js-favorite-restaurant" data-category="restaurant.datasheet" data-cooking-type="Huaiyang" data-country="en" data-dtm-chef="" data-dtm-city="Beijing" data-dtm-distinction="1 star" data-dtm-district="Dongcheng" data-dtm-id="1186722" data-dtm-online-booking="False" data-dtm-price="300 CNY" data-dtm-region="Beijing Municipality" data-enabled="false" data-guide="Global" data-language="en" data-pid="1186722" data-restaurant-country="cn" data-restaurant-name="Huaiyang Fu" data-restaurant-selection="Beijing">
# <img alt="" class="love-this pl-image" src="/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg"/>
# </div>
# </div>
# <a aria-label="Open Huaiyang Fu" class="link with-love" href="/en/beijing-municipality/beijing/restaurant/huaiyang-fu"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height js-map" data-id="75122" data-index="" data-lat="39.937846" data-lng="116.410128">
# <div class="card__menu-image">
# <a aria-label="Open Pang Mei Noodles (Dongcheng)" class="image-wrapper pl-image" data-category="restaurant.datasheet" data-ci-bg-url="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/ae44bc9dc4554089b62341842dea46b9" data-country="en" data-guide="Global" data-image-id="1996013" data-image-source="cloud_image" data-position-x="50" data-position-y="50" href="/en/beijing-municipality/beijing/restaurant/pang-mei-noodles">
# <noscript><img alt="" height="203" src="https://axwwgrkdco.cloudimg.io/v7/__gmpics__/ae44bc9dc4554089b62341842dea46b9" width="362"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <span class="distinction-icon"><img alt="" class="michelin-award" src="/assets/images/icons/bib-gourmand-1cdd0611ba6b620ab4815bed020274dd.svg"/></span>
# </div>
# ...
#             </button>
#         </div>
#
#         <div class="modal-body">
#             <div class="modal-account--content">
#                 <form action="#" method="POST" class="js-auth__profile">
#                     <p class="modal-account--content-tagline">
#                         Select how you prefer your name to appear alongside your photo and include a brief bio if you like.
#                     </p>
#                     {{#error}}
#                     <div class="alert alert-danger js-auth__error-box" role="alert">
#                         {{error}}
#                     </div>
#                     {{/error}}
#                     <div>Display my name as:</div>
#
#                     <div class="modal-account--forms {{#nameNotChecked}}is-invalid{{/nameNotChecked}}">
#                         <div class="form-group modal-account--forms-radio">
#                             <input class="radio-button js-reg__profile_name"
#                                    type="radio"
#                                    name="publicName"
#                                    value="{{fullName}}"
#                                    {{#fullNameChecked}}checked{{/fullNameChecked}}/>
#                             <label for="fullNameProfile">{{fullName}}</label><br>
#                         </div>
#
#                         <div class="form-group modal-account--forms-radio">
#                             <input class="radio-button js-reg__profile_firstname"
#                                    type="radio"
#                                    name="publicName"
#                                    value="{{firstName}}"
#                                    {{^fullNameChecked}}checked{{/fullNameChecked}}/>
#                             <label for="firstNameProfile">{{firstName}}</label><br>
#                         </div>
#                     </div>
#
#                     <div class="form-group">
#                         <label for="about">
#                             About me:
#                         </label>
#                         <input type="text"
#                                class="form-control form-control-borderless js-auth__input-about"
#                                autocomplete="off"
#                                name="about"
#                                placeholder="A few words about yourself"
#                                value="{{about}}"/>
#                     </div>
#
#                     <div class="modal-account--forms">
#                         <div class="form-group submit medium-space center">
#                             <button type="submit"
#                                     class="btn btn-primary js-auth__profile-submit"
#                                     data-message-failed-error="Update profile failed. Please try again later."
#                                     data-event="account.register.username"
#                                     data-category="account.register.username"
#                                     data-country="en"
#                                     data-guide="Global">
#                                 Save
#                                 <i class="spinner-border spinner-border-sm loading js-async-loading d-none"></i>
#                             </button>
#                         </div>
#                     </div>
#                 </form>
#             </div>
#         </div>
#     </div>
# </div>
# </script>
# <script id="auth-profile-success" type="x-tmpl-mustache">
# <div class="modal-dialog modal-lg modal-dialog-centered modal-fullscreen-sm-down">
#     <div class="modal-content">
#         <div class="modal-header">
#             <button type="button"
#                     class="close js-dtm-link js-auth__close-modal"
#                     data-dismiss="modal"
#                     data-reload="true"
#                     aria-label="Close"
#                     data-event="account.creation.completion"
#                     data-category="account.registration.done"
#                     data-country="en"
#                     data-guide="Global">
#                 <span aria-hidden="true"><img src="/assets/images/icons/close.svg" width="24" alt=""/></span>
#             </button>
#         </div>
#
#         <div class="modal-body">
#             <div class="modal-account--content center">
#                 <h1 class="modal-account--content-closehead">
#                     Well Done!
#                 </h1>
#
#                 <p class="modal-account--content-tagline left">
#
#                     You can now start liking your favorite restaurants and create your first list by tapping on the <img src="/assets/images/icons/favorite-heart-e6323193a7a0acd16288e7cf61092d46.gif" width="50" alt=""> icon in restaurants and hotels page.
#                 </p>
#
#                 <div class="modal-account--forms">
#                     <div class="form-group submit center">
#                         <button type="button"
#                                 data-dismiss="modal"
#                                 class="btn btn-primary js-dtm-link js-auth__get-started"
#                                 aria-label="Get Started"
#                                 data-event="account.registration.getStarted"
#                                 data-category="account.registration.done"
#                                 data-country="en"
#                                 data-guide="Global"
#                                 data-reload="true">
#                             Get Started
#                         </button>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
# </script>
# <script id="card-menu_hotelprice" type="x-tmpl-mustache">
#     {{#price}}
#         Starting at
#         <span class="card__menu-content--hotelprice-tag">{{price}}</span>
#     {{/price}}
#     {{^price}}
#         {{#onRequest}}
#             On request
#         {{/onRequest}}
#         {{^onRequest}}
#             Sold out
#         {{/onRequest}}
#     {{/price}}
# </script>
# <script type="text/javascript">
#     window.ALGOLIASEARCH_APP_ID = '8NVHRD7ONV';
#     window.ALGOLIASEARCH_SEARCH_KEY = '3222e669cf890dc73fa5f38241117ba5';
#     window.CLOUDIMAGE_BASE_URL = 'https://axwwgrkdco.cloudimg.io/v7/';
#     window.CLOUDIMAGE_CARD_OPTIONS = 'width=500&sharp=1';
#     window.CLOUDIMAGE_CITY_GUIDE_CARD_OPTIONS = 'width=800&sharp=1';
#     window.CLOUDIMAGE_TOKEN = 'axwwgrkdco';
#     window.DIDOMI_ENABLED = true;
#     window.COOKIE_SECURE = true;
#     window.COOKIE_ACCEPTED = false;
#     window.AWARDS_MAP = {"THREE_STARS":{"icon":"o","label":"3 Stars MICHELIN","awardName":"3 star","slug":"3-stars-michelin"},"TWO_STARS":{"icon":"n","label":"2 Stars MICHELIN","awardName":"2 star","slug":"2-stars-michelin"},"MICHELIN_PLATE":{"icon":"\u2039","label":"The Plate MICHELIN","awardName":"plate","slug":"the-plate-michelin"},"ONE_STAR":{"icon":"m","label":"1 Star MICHELIN","awardName":"1 star","slug":"1-star-michelin"},"BIB_GOURMAND":{"icon":"=","label":"Bib Gourmand","awardName":"bib","slug":"bib-gourmand"}};
#     window.COUNTRIES_MAP = {"pr":{"cname":"puerto-rico","label":"Puerto Rico"},"ps":{"cname":"palestine","label":"Palestine"},"pt":{"cname":"portugal","label":"Portugal"},"pw":{"cname":"palau","label":"Palau"},"py":{"cname":"paraguay","label":"Paraguay"},"qa":{"cname":"qatar","label":"Qatar"},"ad":{"cname":"andorra","label":"Andorra"},"ae":{"cname":"united-arab-emirates","label":"United Arab Emirates"},"af":{"cname":"afghanistan","label":"Afghanistan"},"ag":{"cname":"antigua-and-barbuda","label":"Antigua and Barbuda"},"ai":{"cname":"anguilla","label":"Anguilla"},"al":{"cname":"albania","label":"Albania"},"am":{"cname":"armenia","label":"Armenia"},"an":{"cname":"netherlands-antilles","label":"Netherlands Antilles"},"ao":{"cname":"angola","label":"Angola"},"aq":{"cname":"antarctica","label":"Antarctica"},"ar":{"cname":"argentina","label":"Argentina"},"as":{"cname":"american-samoa","label":"American Samoa"},"at":{"cname":"austria","label":"Austria"},"re":{"cname":"reunion","label":"Reunion"},"au":{"cname":"australia","label":"Australia"},"aw":{"cname":"aruba","label":"Aruba"},"ax":{"cname":"aland-islands","label":"\u00c5land Islands"},"az":{"cname":"azerbaijan","label":"Azerbaijan"},"ro":{"cname":"romania","label":"Romania"},"ba":{"cname":"bosnia-and-herzegovina","label":"Bosnia and Herzegovina"},"bb":{"cname":"barbados","label":"Barbados"},"rs":{"cname":"serbia","label":"Serbia"},"bd":{"cname":"bangladesh","label":"Bangladesh"},"be":{"cname":"belgium","label":"Belgium"},"ru":{"cname":"russia","label":"Russia"},"bf":{"cname":"burkina-faso","label":"Burkina Faso"},"bg":{"cname":"bulgaria","label":"Bulgaria"},"rw":{"cname":"rwanda","label":"Rwanda"},"bh":{"cname":"bahrain","label":"Bahrain"},"bi":{"cname":"burundi","label":"Burundi"},"bj":{"cname":"benin","label":"Benin"},"bl":{"cname":"saint-barthelemy","label":"Saint Barth\u00e9lemy"},"bm":{"cname":"bermuda","label":"Bermuda"},"bn":{"cname":"brunei","label":"Brunei"},"bo":{"cname":"bolivia","label":"Bolivia"},"sa":{"cname":"saudi-arabia","label":"Saudi Arabia"},"bq":{"cname":"bonaire-sint-eustatius-and-saba","label":"Bonaire, Sint Eustatius and Saba"},"sb":{"cname":"solomon-islands","label":"Solomon Islands"},"br":{"cname":"brazil","label":"Brazil"},"sc":{"cname":"seychelles","label":"Seychelles"},"bs":{"cname":"bahamas","label":"Bahamas"},"sd":{"cname":"sudan","label":"Sudan"},"bt":{"cname":"bhutan","label":"Bhutan"},"se":{"cname":"sweden","label":"Sweden"},"bv":{"cname":"bouvet-island","label":"Bouvet Island"},"sg":{"cname":"singapore","label":"Singapore"},"bw":{"cname":"botswana","label":"Botswana"},"sh":{"cname":"saint-helena","label":"Saint Helena"},"si":{"cname":"slovenia","label":"Slovenia"},"by":{"cname":"belarus","label":"Belarus"},"sj":{"cname":"svalbard-and-jan-mayen","label":"Svalbard And Jan Mayen"},"bz":{"cname":"belize","label":"Belize"},"sk":{"cname":"slovakia","label":"Slovakia"},"sl":{"cname":"sierra-leone","label":"Sierra Leone"},"sm":{"cname":"san-marino","label":"San Marino"},"sn":{"cname":"senegal","label":"Senegal"},"so":{"cname":"somalia","label":"Somalia"},"ca":{"cname":"canada","label":"Canada"},"sr":{"cname":"suriname","label":"Suriname"},"cc":{"cname":"cocos-islands","label":"Cocos Islands"},"ss":{"cname":"south-sudan","label":"South Sudan"},"cd":{"cname":"the-democratic-republic-of-congo","label":"The Democratic Republic Of Congo"},"st":{"cname":"sao-tome-and-principe","label":"Sao Tome And Principe"},"cf":{"cname":"central-african-republic","label":"Central African Republic"},"sv":{"cname":"el-salvador","label":"El Salvador"},"cg":{"cname":"congo","label":"Congo"},"ch":{"cname":"switzerland","label":"Switzerland"},"sx":{"cname":"sint-maarten-dutch-part","label":"Sint Maarten (Dutch part)"},"ci":{"cname":"cote-d-ivoire","label":"C\u00f4te d'Ivoire"},"sy":{"cname":"syria","label":"Syria"},"sz":{"cname":"swaziland","label":"Swaziland"},"ck":{"cname":"cook-islands","label":"Cook Islands"},"cl":{"cname":"chile","label":"Chile"},"cm":{"cname":"cameroon","l ...
#     window.LANGUAGE_CODES_MAP = {"de":"deu","ko":"kor","en":"eng","pt_BR":"por","it":"ita","fr":"fra","es":"spa","ar":"ara","zh_HK":"zho","zh_TW":"zho","th":"tha","ja":"jpn","zh_CN":"zho","nl":"nld","tr":"tur","pt_PT":"por"};
#     window.RESTAURANT_PLACEHOLDER_IMAGES = ["https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/default1.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/default2.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-119577476.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-157185809.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-179536318.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-182146474.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-509105428.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-542825520.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-544123256.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-677785016.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-810733288.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-839150516.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/online_list_default_0.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/online_list_default_1.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_0.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_1.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_2.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_3.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_5.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_6.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_7.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_9.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_10.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_11.jpg"];
#     window.GCJ02_CANDIDATES = ["cn","tw"];
#     window.SITE_NAME_TRANSLATIONS = {};
#     window.TABLETHOTELS_HOTELS_BASE = 'https://www.tablethotels.com';
#     window.TABLETHOTELS_API_OLD_BASE = 'https://www.tablethotels.com';
#     window.TABLETHOTELS_API_BASE = 'https://api.prod.r53.tablethotels.com';
#     window.HOTEL_COUNTRY = '';
#     window.HOTEL_CURRENCY = 'USD';
#     window.HOTEL_VIEWPORT = '';
#     window.CONTENT_OPTIONAL_TAGS = {};
#     window.CONTACT_US_SUBJECTS = {};
#     window.PRICE_CATEGORIES = {"affordable":{"identifier":"CAT_P01","multiplier":1,"label":"On a budget"},"premium":{"identifier":"CAT_P03","multiplier":3,"label":"Special occasion"},"mid-range":{"identifier":"CAT_P02","multiplier":2,"label":"A moderate spend"},"luxury":{"identifier":"CAT_P04","multiplier":4,"label":"Spare no expense"}};
#     window.SITE_CURRENCY = '';
#     window.IS_ACCOUNT_DISABLED = false;
#     window.LOVE_ON_ICON = '/assets/images/icons/love-on-fc56a08bc4382811985ec658b8fd4bf5.svg';
#     window.LOVE_OFF_ICON = '/assets/images/icons/love-off-58dca5751a8ad8f50468df25d762b097.svg';
# </script>
# <script src="//polyfill.io/v3/polyfill.min.js?features=default,Array.prototype.find,Array.prototype.includes"></script>
# <script charset="utf-8" src="/assets/web/app.guide-d5344bb8f0f777d2d217fa19800d2eac.js" type="text/javascript"></script>
# <script type="application/ld+json">{"@context":"http://schema.org","address":{"@type":"PostalAddress","streetAddress":"2 Wudaoying Hutong","addressLocality":"Beijing","addressCountry":"CHN","addressRegion":"Beijing Municipality"},"name":"King's Joy","image":"https://axwwgrkdco.cloudimg.io/v7/__gmpics__/1a95e7f7baff4811a672aa337cc0a16c?width=1000","@type":"Restaurant","review":{"@type":"Review","datePublished":"2022-12-20T08:09","name":"King's Joy","description":"Just a stone\u2019s throw from Yonghe Temple, this serene restaurant is remodelled from a courtyard house and features a glass-roofed dining room. The chef honed his skills at his grandparents\u2019 ...","author":{"@type":"Person","name":"Michelin Inspector"}},"telephone":"+86 10 8404 9191","knowsLanguage":"en-CN","acceptsReservations":"No","servesCuisine":"Vegetarian","url":"https://guide.michelin.com/en/beijing-municipality/beijing/restaurant/king-s-joy","starRating":"Three MICHELIN Stars: Exceptional cuisine, worth a special journey!","currenciesAccepted":"CNY","paymentAccepted":"American Express credit card, China UnionPay, Credit card / Debit card accepted, Diners Club credit card, JCB, Maestro, Mastercard credit card, Visa credit card","award":"Three MICHELIN Stars: Exceptional cuisine, worth a special journey!","brand":"MICHELIN Guide","hasDriveThroughService":"False","latitude":39.9466810,"longitude":116.4100040,"hasMap":"https://www.google.com/maps/search/?api=1&query=39.9466810%2C116.4100040"}</script>
# </body>
# </html>

# %%
#Located at div class="restaurant-details__description--text
path2 = soup2.find('div', class_='restaurant-details__description--text').find('p')

# %%
path2
# Out:
# <p>This branch of the chain restaurant opened in 2019 and features an elegant but relaxed dining room decorated in a modern Chinese style. Counter seats affording views of the open kitchen are good for couples or solo diners. The menu is essentially the same as other branches, focusing on Taizhou and Cantonese cooking, and fish from the East China Sea. But the 28-day-old baby Peking duck is available exclusively at this location and needs pre-ordering.</p>

# %%
#Trying to strip the newline characters
path2 = soup2.find('div', class_='restaurant-details__description--text').find('p').text.strip()
path2
# Out:
# 'This branch of the chain restaurant opened in 2019 and features an elegant but relaxed dining room decorated in a modern Chinese style. Counter seats affording views of the open kitchen are good for couples or solo diners. The menu is essentially the same as other branches, focusing on Taizhou and Cantonese cooking, and fish from the East China Sea. But the 28-day-old baby Peking duck is available exclusively at this location and needs pre-ordering.'

# %%
anchor = path2.find('p')
anchor
# Out:
# <p>This branch of the chain restaurant opened in 2019 and features an elegant but relaxed dining room decorated in a modern Chinese style. Counter seats affording views of the open kitchen are good for couples or solo diners. The menu is essentially the same as other branches, focusing on Taizhou and Cantonese cooking, and fish from the East China Sea. But the 28-day-old baby Peking duck is available exclusively at this location and needs pre-ordering.</p>

# %%
#try on 5
def get_michelin_pages_test5():
    df = pd.read_pickle('data/dftest5.pickle')
    urls = df['url']
    output = []
    for url in urls:
        try:
            request = requests.get(url)
            soup = BeautifulSoup(request.content, 'html.parser')
            page_output = soup.find('div', class_='restaurant-details__description--text').find('p').text.strip()
            text = page_output
            output.append(page_output)
            time.sleep(2)
        except requests.exceptions.RequestException as e:
            print(e)
            continue
    df['data'] = output
    return df

# %%
df5 = get_michelin_pages_test5()

# %%
#Looks good
df5.head()
# Out:
#                                name  \
# 0                        King's Joy
# 1  Xin Rong Ji (Xinyuan South Road)
# 2                       Taian Table
# 3        Ultraviolet by Paul Pairet
# 4                            Quince
#
#                                              address  \
# 0        2 Wudaoying Hutong, Beijing, China Mainland
# 1  1F, East Tower, Genesis Beijing, 8 Xinyuan Sou...
# 2  101-102, Building No. 1, Garden Office, No.161...
# 3  'somewhere in Shanghai' - meet at Mr & Mrs Bun...
# 4        470 Pacific Ave., San Francisco, 94133, USA
#
#                    location price                    cuisine   longitude  \
# 0   Beijing, China Mainland   ¥¥¥                 Vegetarian  116.410004
# 1   Beijing, China Mainland  ¥¥¥¥                    Taizhou  116.450148
# 2  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.474049
# 3  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.485090
# 4        San Francisco, USA  $$$$  Contemporary, Californian -122.403261
#
#     latitude  phone_number                                                url  \
# 0  39.946681  8.610840e+11  https://guide.michelin.com/en/beijing-municipa...
# 1  39.946380  8.610650e+11  https://guide.michelin.com/en/beijing-municipa...
# 2  31.221807  8.617302e+12  https://guide.michelin.com/en/shanghai-municip...
# 3  31.240358           NaN  https://guide.michelin.com/en/shanghai-municip...
# 4  37.797505  1.415776e+10  https://guide.michelin.com/en/california/san-f...
#
#                        website_url             award  \
# 0                              NaN  3 MICHELIN Stars
# 1                              NaN  3 MICHELIN Stars
# 2          https://taian-table.cn/  3 MICHELIN Stars
# 3               https://uvbypp.cc/  3 MICHELIN Stars
# 4  http://www.quincerestaurant.com  3 MICHELIN Stars
#
#                              facilities_and_services  \
# 0  Air conditioning,American Express credit card,...
# 1  Air conditioning,Car park,China UnionPay,Count...
# 2  Air conditioning,American Express credit card,...
# 3  Air conditioning,American Express credit card,...
# 4  Air conditioning,American Express credit card,...
#
#                                                parts  \
# 0  beijing-municipality/beijing/restaurant/king-s...
# 1  beijing-municipality/beijing/restaurant/xin-ro...
# 2  shanghai-municipality/shanghai/restaurant/taia...
# 3  shanghai-municipality/shanghai/restaurant/ultr...
# 4         california/san-francisco/restaurant/quince
#
#                                                 data
# 0  Just a stone’s throw from Yonghe Temple, this ...
# 1  This branch of the chain restaurant opened in ...
# 2  A fixture on the city’s dining scene since 201...
# 3  This multi-sensory experience at a secret loca...
# 4  An air of refinement infuses this dining room,...

# %%
#Now crossing our fingers for 100

# %%
#This works!
def get_michelin_pages_test100():
    df = pd.read_pickle('data/dftest100.pickle')
    urls = df['url']
    output = []
    for url in urls:
        try:
            request = requests.get(url)
            soup = BeautifulSoup(request.content, 'html.parser')
            page_output = soup.find('div', class_='restaurant-details__description--text').find('p').text.strip()
            text = page_output
            output.append(page_output)
            time.sleep(2)
        except AttributeError:
            page_output = 'None'
            output.append(page_output)
            continue
    df['data'] = output
    return df

# %%
df100 = get_michelin_pages_test100()
df100.head()
# Out:
#                                name  \
# 0                        King's Joy
# 1  Xin Rong Ji (Xinyuan South Road)
# 2                       Taian Table
# 3        Ultraviolet by Paul Pairet
# 4                            Quince
#
#                                              address  \
# 0        2 Wudaoying Hutong, Beijing, China Mainland
# 1  1F, East Tower, Genesis Beijing, 8 Xinyuan Sou...
# 2  101-102, Building No. 1, Garden Office, No.161...
# 3  'somewhere in Shanghai' - meet at Mr & Mrs Bun...
# 4        470 Pacific Ave., San Francisco, 94133, USA
#
#                    location price                    cuisine   longitude  \
# 0   Beijing, China Mainland   ¥¥¥                 Vegetarian  116.410004
# 1   Beijing, China Mainland  ¥¥¥¥                    Taizhou  116.450148
# 2  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.474049
# 3  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.485090
# 4        San Francisco, USA  $$$$  Contemporary, Californian -122.403261
#
#     latitude  phone_number                                                url  \
# 0  39.946681  8.610840e+11  https://guide.michelin.com/en/beijing-municipa...
# 1  39.946380  8.610650e+11  https://guide.michelin.com/en/beijing-municipa...
# 2  31.221807  8.617302e+12  https://guide.michelin.com/en/shanghai-municip...
# 3  31.240358           NaN  https://guide.michelin.com/en/shanghai-municip...
# 4  37.797505  1.415776e+10  https://guide.michelin.com/en/california/san-f...
#
#                        website_url             award  \
# 0                              NaN  3 MICHELIN Stars
# 1                              NaN  3 MICHELIN Stars
# 2          https://taian-table.cn/  3 MICHELIN Stars
# 3               https://uvbypp.cc/  3 MICHELIN Stars
# 4  http://www.quincerestaurant.com  3 MICHELIN Stars
#
#                              facilities_and_services  \
# 0  Air conditioning,American Express credit card,...
# 1  Air conditioning,Car park,China UnionPay,Count...
# 2  Air conditioning,American Express credit card,...
# 3  Air conditioning,American Express credit card,...
# 4  Air conditioning,American Express credit card,...
#
#                                                parts  \
# 0  beijing-municipality/beijing/restaurant/king-s...
# 1  beijing-municipality/beijing/restaurant/xin-ro...
# 2  shanghai-municipality/shanghai/restaurant/taia...
# 3  shanghai-municipality/shanghai/restaurant/ultr...
# 4         california/san-francisco/restaurant/quince
#
#                                                 data
# 0  Just a stone’s throw from Yonghe Temple, this ...
# 1  This branch of the chain restaurant opened in ...
# 2  A fixture on the city’s dining scene since 201...
# 3  This multi-sensory experience at a secret loca...
# 4  An air of refinement infuses this dining room,...

# %%
#trying to rewrite function to use multiple selectors
def get_soup_multiple_ways_test5():
    df = pd.read_pickle('data/dftest5.pickle')
    urls = df['url']
    output = []
    for url in urls:
        request = requests.get(url)
        soup = BeautifulSoup(request.content, 'html.parser')
        try:
            page_output = soup.find('div', 
                                    class_='restaurant-details__description--text').find('p').text.strip()
        except:
            page_output = soup.find('div', 
                                    class_='restaurant-details__description--text').find('p',{'class':None}).text.strip()
        output.append(page_output)
        time.sleep(2)
    df['data'] = output
    return df

# %%
df = get_soup_multiple_ways_test5()
df.head()
# Out:
#                                name  \
# 0                        King's Joy
# 1  Xin Rong Ji (Xinyuan South Road)
# 2                       Taian Table
# 3        Ultraviolet by Paul Pairet
# 4                            Quince
#
#                                              address  \
# 0        2 Wudaoying Hutong, Beijing, China Mainland
# 1  1F, East Tower, Genesis Beijing, 8 Xinyuan Sou...
# 2  101-102, Building No. 1, Garden Office, No.161...
# 3  'somewhere in Shanghai' - meet at Mr & Mrs Bun...
# 4        470 Pacific Ave., San Francisco, 94133, USA
#
#                    location price                    cuisine   longitude  \
# 0   Beijing, China Mainland   ¥¥¥                 Vegetarian  116.410004
# 1   Beijing, China Mainland  ¥¥¥¥                    Taizhou  116.450148
# 2  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.474049
# 3  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.485090
# 4        San Francisco, USA  $$$$  Contemporary, Californian -122.403261
#
#     latitude  phone_number                                                url  \
# 0  39.946681  8.610840e+11  https://guide.michelin.com/en/beijing-municipa...
# 1  39.946380  8.610650e+11  https://guide.michelin.com/en/beijing-municipa...
# 2  31.221807  8.617302e+12  https://guide.michelin.com/en/shanghai-municip...
# 3  31.240358           NaN  https://guide.michelin.com/en/shanghai-municip...
# 4  37.797505  1.415776e+10  https://guide.michelin.com/en/california/san-f...
#
#                        website_url             award  \
# 0                              NaN  3 MICHELIN Stars
# 1                              NaN  3 MICHELIN Stars
# 2          https://taian-table.cn/  3 MICHELIN Stars
# 3               https://uvbypp.cc/  3 MICHELIN Stars
# 4  http://www.quincerestaurant.com  3 MICHELIN Stars
#
#                              facilities_and_services  \
# 0  Air conditioning,American Express credit card,...
# 1  Air conditioning,Car park,China UnionPay,Count...
# 2  Air conditioning,American Express credit card,...
# 3  Air conditioning,American Express credit card,...
# 4  Air conditioning,American Express credit card,...
#
#                                                parts  \
# 0  beijing-municipality/beijing/restaurant/king-s...
# 1  beijing-municipality/beijing/restaurant/xin-ro...
# 2  shanghai-municipality/shanghai/restaurant/taia...
# 3  shanghai-municipality/shanghai/restaurant/ultr...
# 4         california/san-francisco/restaurant/quince
#
#                                                 data
# 0  Just a stone’s throw from Yonghe Temple, this ...
# 1  This branch of the chain restaurant opened in ...
# 2  A fixture on the city’s dining scene since 201...
# 3  This multi-sensory experience at a secret loca...
# 4  An air of refinement infuses this dining room,...

# %%
#now trying for 100
#trying to rewrite function to use multiple selectors
def get_soup_multiple_ways_test100():
    df = pd.read_pickle('data/dftest100.pickle')
    urls = df['url']
    output = []
    for url in urls:
        request = requests.get(url)
        soup = BeautifulSoup(request.content, 'html.parser')
        try:
            page_output = soup.find('div',class_='restaurant-details__description--text').find('p').text.strip()
            return page_output
        except:
            page_output = soup.find('div',class_='restaurant-details__description--text').find('p',{'class':None}).text.strip()
            return page_output
        except AttributeError:
            return page_output == 'None'
        output.append(page_output)
        time.sleep(2)
    df['data'] = output
    return df
# Out:
#   Cell In[111], line 12
#     return page_output
#     ^
# SyntaxError: default 'except:' must be last

# %%
df100 = get_soup_multiple_ways_test100()
df100.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[92], line 11, in get_soup_multiple_ways_test100()
#      10 try:
# ---> 11     page_output = soup.find('div',
#      12                             class_='restaurant-details__description--text').find('p').text.strip()
#      13 except:
#
# AttributeError: 'NoneType' object has no attribute 'find'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 df100 = get_soup_multiple_ways_test100()
#       2 df100.head()
#
# Cell In[92], line 14, in get_soup_multiple_ways_test100()
#      11     page_output = soup.find('div',
#      12                             class_='restaurant-details__description--text').find('p').text.strip()
#      13 except:
# ---> 14     page_output = soup.find('div',
#      15                             class_='restaurant-details__description--text').find('p',{'class':None}).text.strip()
#      16 output.append(page_output)
#      17 time.sleep(2)
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
#Trying to rewrite the function again
def get_soup_multiple_ways_test100():
    df = pd.read_pickle('data/dftest100.pickle')
    urls = df['url']
    output = []
    for url in urls:
        request = requests.get(url)
        soup = BeautifulSoup(request.content, 'html.parser')
        try:
            page_output = soup.find('div',class_='restaurant-details__description--text').find('p').text.strip()
        except AttributeError:
            page_output = soup.find('div',class_='restaurant-details__description--text').find('p',{'class':None}).text.strip()
            if page_output is None:
                page_output = 'None'
            continue
    output.append(page_output)
    time.sleep(2)
    df['data'] = output
    return df

# %%
df = get_soup_multiple_ways_test100()
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[125], line 10, in get_soup_multiple_ways_test100()
#       9 try:
# ---> 10     page_output = soup.find('div',class_='restaurant-details__description--text').find('p').text.strip()
#      11 except AttributeError:
#
# AttributeError: 'NoneType' object has no attribute 'find'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 df = get_soup_multiple_ways_test100()
#       2 df.head()
#
# Cell In[125], line 12, in get_soup_multiple_ways_test100()
#      10     page_output = soup.find('div',class_='restaurant-details__description--text').find('p').text.strip()
#      11 except AttributeError:
# ---> 12     page_output = soup.find('div',class_='restaurant-details__description--text').find('p',{'class':None}).text.strip()
#      13     if page_output is None:
#      14         page_output = 'None'
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
df.head(2)
# Out:
#                                name  \
# 0                        King's Joy
# 1  Xin Rong Ji (Xinyuan South Road)
#
#                                              address                 location  \
# 0        2 Wudaoying Hutong, Beijing, China Mainland  Beijing, China Mainland
# 1  1F, East Tower, Genesis Beijing, 8 Xinyuan Sou...  Beijing, China Mainland
#
#   price     cuisine   longitude   latitude  phone_number  \
# 0   ¥¥¥  Vegetarian  116.410004  39.946681  8.610840e+11
# 1  ¥¥¥¥     Taizhou  116.450148  39.946380  8.610650e+11
#
#                                                  url website_url  \
# 0  https://guide.michelin.com/en/beijing-municipa...         NaN
# 1  https://guide.michelin.com/en/beijing-municipa...         NaN
#
#               award                            facilities_and_services
# 0  3 MICHELIN Stars  Air conditioning,American Express credit card,...
# 1  3 MICHELIN Stars  Air conditioning,Car park,China UnionPay,Count...

# %%
#Make a dataframe of the first 10 to capture the error
df[:10].to_pickle('data/dftest10.pickle')

# %%
df10 = pd.read_pickle('data/dftest10.pickle')
df10
# Out:
#                                name  \
# 0                        King's Joy
# 1  Xin Rong Ji (Xinyuan South Road)
# 2                       Taian Table
# 3        Ultraviolet by Paul Pairet
# 4                            Quince
# 5                     Atelier Crenn
# 6                           Addison
# 7                           Manresa
# 8                              Benu
# 9                      SingleThread
#
#                                              address  \
# 0        2 Wudaoying Hutong, Beijing, China Mainland
# 1  1F, East Tower, Genesis Beijing, 8 Xinyuan Sou...
# 2  101-102, Building No. 1, Garden Office, No.161...
# 3  'somewhere in Shanghai' - meet at Mr & Mrs Bun...
# 4        470 Pacific Ave., San Francisco, 94133, USA
# 5       3127 Fillmore St., San Francisco, 94123, USA
# 6      5200 Grand Del Mar Way, San Diego, 92130, USA
# 7             320 Village Ln., Los Gatos, 95030, USA
# 8        22 Hawthorne St., San Francisco, 94105, USA
# 9              131 North St., Healdsburg, 95448, USA
#
#                    location price                    cuisine   longitude  \
# 0   Beijing, China Mainland   ¥¥¥                 Vegetarian  116.410004
# 1   Beijing, China Mainland  ¥¥¥¥                    Taizhou  116.450148
# 2  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.474049
# 3  Shanghai, China Mainland  ¥¥¥¥                 Innovative  121.485090
# 4        San Francisco, USA  $$$$  Contemporary, Californian -122.403261
# 5        San Francisco, USA  $$$$       Contemporary, French -122.435860
# 6            San Diego, USA  $$$$  Contemporary, Californian -117.198891
# 7            Los Gatos, USA  $$$$  Contemporary, Californian -121.980710
# 8        San Francisco, USA  $$$$        Asian, Contemporary -122.399060
# 9           Healdsburg, USA  $$$$  Contemporary, Californian -122.869723
#
#     latitude  phone_number                                                url  \
# 0  39.946681  8.610840e+11  https://guide.michelin.com/en/beijing-municipa...
# 1  39.946380  8.610650e+11  https://guide.michelin.com/en/beijing-municipa...
# 2  31.221807  8.617302e+12  https://guide.michelin.com/en/shanghai-municip...
# 3  31.240358           NaN  https://guide.michelin.com/en/shanghai-municip...
# 4  37.797505  1.415776e+10  https://guide.michelin.com/en/california/san-f...
# 5  37.798350  1.415440e+10  https://guide.michelin.com/en/california/san-f...
# 6  32.941297  1.858314e+10  https://guide.michelin.com/en/california/us-sa...
# 7  37.227610  1.408354e+10  https://guide.michelin.com/en/california/los-g...
# 8  37.785376  1.415685e+10  https://guide.michelin.com/en/california/san-f...
# 9  38.612260  1.707723e+10  https://guide.michelin.com/en/california/heald...
#
#                           website_url             award  \
# 0                                 NaN  3 MICHELIN Stars
# 1                                 NaN  3 MICHELIN Stars
# 2             https://taian-table.cn/  3 MICHELIN Stars
# 3                  https://uvbypp.cc/  3 MICHELIN Stars
# 4     http://www.quincerestaurant.com  3 MICHELIN Stars
# 5       https://www.ateliercrenn.com/  3 MICHELIN Stars
# 6      https://www.addisondelmar.com/  3 MICHELIN Stars
# 7  https://www.manresarestaurant.com/  3 MICHELIN Stars
# 8             https://www.benusf.com/  3 MICHELIN Stars
# 9  https://www.singlethreadfarms.com/  3 MICHELIN Stars
#
#                              facilities_and_services
# 0  Air conditioning,American Express credit card,...
# 1  Air conditioning,Car park,China UnionPay,Count...
# 2  Air conditioning,American Express credit card,...
# 3  Air conditioning,American Express credit card,...
# 4  Air conditioning,American Express credit card,...
# 5  Air conditioning,Credit card / Debit card acce...
# 6  Air conditioning,American Express credit card,...
# 7  Air conditioning,Credit card / Debit card acce...
# 8  Air conditioning,Credit card / Debit card acce...
# 9  Air conditioning,Credit card / Debit card acce...

# %%
df100[df100.data == 'None']
# Out:
#       name                                 address        location price  \
# 7  Manresa  320 Village Ln., Los Gatos, 95030, USA  Los Gatos, USA  $$$$
#
#                      cuisine  longitude  latitude  phone_number  \
# 7  Contemporary, Californian -121.98071  37.22761  1.408354e+10
#
#                                                  url  \
# 7  https://guide.michelin.com/en/california/los-g...
#
#                           website_url             award  \
# 7  https://www.manresarestaurant.com/  3 MICHELIN Stars
#
#                              facilities_and_services  \
# 7  Air conditioning,Credit card / Debit card acce...
#
#                                      parts  data
# 7  california/los-gatos/restaurant/manresa  None

# %%
df100.url[7]
# Out:
# 'https://guide.michelin.com/en/california/los-gatos/restaurant/manresa'

# %%
df.to_pickle('data/df100_complete.pickle')

# %%
#Now lets go for it all!
